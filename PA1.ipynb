# %% [markdown]
# # PA 1: Exploratory Analysis over Federal Emergencies and Disasters

# %% [markdown]
# ## Student Details
#
# Notes:
# When submitting, fill your name and ID in this cell. Note that this is a markdown cell!
# Do not make any changes in the dataset file and do not rename the 'database.csv'.
# Rename your submission file to <b> 'yourLastName_Last4digitsofyourID_PA1.ipynb' </b>.
# Do not to forget to cite any external sources used by you.
# [2.5 points]

# %% [markdown]
# ## Assignment Details
#
# In this assignment, you will conduct a guided exploration over the Federal Emergencies and Disasters dataset. You will learn and use some of the most common exploration/aggregation/descriptive operations. This should also help you learn most of the key functionalities in Pandas.
#
# You will also learn how to use visualization libraries to identify patterns in data that will help in your further data analysis. You will also explore most popular chart types and how to use different libraries and styles to make your visualizations more attractive.

# %% [markdown]
# ## Dataset Details
#
# In this assignment, you will work on 63 years of Federal Disasters dataset. Specifically, you will work on database.csv file from kaggle repository (https://www.kaggle.com/fema/federal-disasters). The file database.csv contains 46,184 rows and 14 columns. This dataset begins with the year 1953, and runs up to the year 2017. Each row corresponds to an emergency declared by the president due to a natural disaster all around the US. The columns of the data-set are:
# - Declaration Number - Unique number for each emergency declared
# - Declaration Type - Type of declaration
# - Declaration Date - Date of declaration
# - State - State affected
# - County - County affected
# - Disaster Type
# - Disaster Title
# - Start Date - The date event started
# - End Date - The date event ended
# - Close Date - End of Declaration
# - Individual Assistance Program - Whether IAP was provided or not?
# - Individuals & Households Program - Whether IHP was provided or not?
# - Public Assistance Program - Whether PAP was provided or not?
# - Hazard Mitigation Program - Whether HMP was provided or not?

# %% [markdown]
# ## Required Python Packages
# You will use the packages imported below in this assignment.
# Do NOT import any new packages without confirming with the TA.

# %%
# special IPython command to prepare the notebook for matplotlib
# %matplotlib inline 

import sys
#Array processing
import numpy as np
#Data analysis, wrangling and common exploratory operations
import pandas as pd
from pandas import Series, DataFrame

#For visualization. Matplotlib for basic viz and seaborn for more stylish figures
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading Dataset
# The Python code below reads the Federal Emergencies and Disasters dataset into a Pandas data frame with the name df_data.
# For this code to work, the file 'database.csv' must be in the same folder as this file.

# %%
#read the csv file into a Pandas data frame
df_data = pd.read_csv('database.csv', encoding='latin1')

#return the first 5 rows of the dataset
df_data.head()
# Out:
#   Declaration Number Declaration Type Declaration Date State County  \
# 0               DR-1         Disaster       05/02/1953    GA    NaN
# 1               DR-2         Disaster       05/15/1953    TX    NaN
# 2               DR-3         Disaster       05/29/1953    LA    NaN
# 3               DR-4         Disaster       06/02/1953    MI    NaN
# 4               DR-5         Disaster       06/06/1953    MT    NaN
#
#   Disaster Type              Disaster Title  Start Date    End Date  \
# 0       Tornado                     Tornado  05/02/1953  05/02/1953
# 1       Tornado  Tornado and Heavy Rainfall  05/15/1953  05/15/1953
# 2         Flood                       Flood  05/29/1953  05/29/1953
# 3       Tornado                     Tornado  06/02/1953  06/02/1953
# 4         Flood                      Floods  06/06/1953  06/06/1953
#
#    Close Date Individual Assistance Program Individuals & Households Program  \
# 0  06/01/1954                           Yes                               No
# 1  01/01/1958                           Yes                               No
# 2  02/01/1960                           Yes                               No
# 3  02/01/1956                           Yes                               No
# 4  12/01/1955                           Yes                               No
#
#   Public Assistance Program Hazard Mitigation Program
# 0                       Yes                       Yes
# 1                       Yes                       Yes
# 2                       Yes                       Yes
# 3                       Yes                       Yes
# 4                       Yes                       Yes

# %% [markdown]
# # Task 1: Statistical Exploratory Data Analysis
# Let us start with getting to know the dataset. Your first task will be to get some basic information by using Pandas features.

# %%
#For each task below, look for a Pandas function to do the task.
#Replace None in each task with your code.

# 2.5 points
#Task 1-a: Print the details of the df_data data frame (information such as number of rows,columns, name of columns, etc)
print (">>Task 1-a: Details of df_data data frame are: \n", df_data.info() ) 

# 2.5 points
#Task 1-b: Find the number of rows and columns in the df_data data frame.
num_rows = df_data.shape[0]
num_cols = df_data.shape[1]
print ("\n\n>>Task 1-b: Number of rows:%s and number of columns:%s" % (num_rows, num_cols)) 

# 2.5 points
#Task 1-c: Print the descriptive detail (count, unique, top, freq etc) for 'Start Date' column of the df_data 

print ("\n\n>>Task 1-c: Descriptive details of 'Start Date' column are\n",pd.to_datetime(df_data['Start Date']).describe())

# 10 points
#Task 1-d: Print ALL the unique values of Disaster Title and Counties  .
np.set_printoptions(threshold=sys.maxsize) #To print all entries
disaster_title_list  = df_data['Disaster Title'].unique()
unique_county_list = df_data['County'].unique()

print ("\n\n >>Task 1-d:")
print(disaster_title_list)
print("#####################################################")
print(unique_county_list)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46185 entries, 0 to 46184
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Declaration Number                46185 non-null  object
#  1   Declaration Type                  46185 non-null  object
#  2   Declaration Date                  46185 non-null  object
#  3   State                             46185 non-null  object
#  4   County                            45988 non-null  object
#  5   Disaster Type                     46185 non-null  object
#  6   Disaster Title                    46185 non-null  object
#  7   Start Date                        46185 non-null  object
#  8   End Date                          45843 non-null  object
#  9   Close Date                        35210 non-null  object
#  10  Individual Assistance Program     46185 non-null  object
#  11  Individuals & Households Program  46185 non-null  object
#  12  Public Assistance Program         46185 non-null  object
#  13  Hazard Mitigation Program         46185 non-null  object
# dtypes: object(14)
# memory usage: 4.9+ MB
# >>Task 1-a: Details of df_data data frame are:
#  None
#
#
# >>Task 1-b: Number of rows:46185 and number of columns:14
#
#
# >>Task 1-c: Descriptive details of 'Start Date' column are
#  count                   46185
# unique                   2324
# top       2005-08-29 00:00:00
# freq                     2764
# first     1953-05-02 00:00:00
# last      2017-02-07 00:00:00
# Name: Start Date, dtype: object
#
#
#  >>Task 1-d:
# ['Tornado' 'Tornado and Heavy Rainfall' 'Flood' 'Floods' 'Forest Fire'
#  'Severe Hardship' 'Flood and Erosion' 'Earthquake' 'Hurricanes'
#  'Hurricane' 'Volcano' 'Flood and Tornado' 'Hurricane and Flood'
#  'Floods and Rains' 'Hurricane and Floods'
#  'Hurricane, Torrential Rain, and Floods' 'Tornadoes' 'Severe Storm'
#  'Wind Storm' 'Storm and Flood' 'Storm' 'Tidal Wave'
#  'Hurricane, Rain, Wind, Hail, and Floods' 'Floods and Hurricane'
#  'Tornadoes and Floods' 'Tornadoes, Rain, Hail, and Floods'
#  'Heavy Rainstorms and Flood' 'Heavy Rainstorms and Floods'
#  'Tornadoes, Rain, Hail and Floods' 'Hurricane and Severe Storm'
#  'Hurricane Dot' 'Heavy Rains and Floods'
#  'Earthquakes and Volcanic Disturbances' 'Severe Weather Conditions'
#  'Tidal Waves' 'Heavy Rains, Hail, Floods, and Tornadoes' 'Fires'
#  'Hurricane Donna' 'Floods and Tornadoes' 'Hurricane Carla' 'Fire'
#  'Severe Storms, High Tides, and Flooding'
#  'Severe Storm, High Tides, and Flooding' 'Chlorine Barge Accident'
#  'Severe Storms' 'Severe Storms and Flooding' 'Typhoon Karen' 'High Tides'
#  'Severe Storms, Heavy Rains, and Flooding' 'Heavy Rains and Flooding'
#  'Typhoon Olive' 'Hurricane Cindy' 'Drought and Impending Freeze'
#  'Flood Due to Broken Dam' 'Flooding' 'Seismic Sea Wave'
#  'Extreme Drought Conditions' 'Hurricane Cleo' 'Hurricane Dora'
#  'Hurricane Hilda' 'Typhoon Louise' 'Severe Winter Storm'
#  'Tornadoes and Severe Storms' 'Tornadoes, Severe Storms, and Flooding'
#  'Tornadoes and Flooding' 'Water Shortage' 'Hurricane Betsy'
#  'Typhoon and High Tides' 'Typhoon Sally' 'Forest Fires'
#  'Hurricane Beulah' 'Severe Ice Storm' 'Typhoon Jean'
#  'Tornado and Severe Storm' 'Severe Storms, High Winds, and Flooding'
#  'Hurricane Gladys' 'Hurricane Camille' 'Heavy Rains and Landslide'
#  'Heavy Snowmelt, Rains, and Flooding'
#  'Severe Storms, Ice Jams, and Flooding'
#  'Heavy Rains, Tornadoes, and Flooding'
#  'Tornadoes, Windstorms, and Flooding' 'Hurricane Celia'
#  'Heavy Rains and Flash' 'Forest and Brush Fires'
#  'San Fernando Earthquake' 'Heavy Rains, Melting Snows, and Flooding'
#  'Storms and Flooding' 'Storms and Tornadoes' 'Freeze' 'Typhoon Amy'
#  'Heavy Rains, High Winds, and Flooding' 'Hurricane Edith'
#  'Winds, Flooding, and Mudslides' 'Severe Storms and Extensive Flooding'
#  'Coastal Storms' 'Severe Storm and Freezing' 'Tropical Storm Agnes'
#  'Flooding Caused by Levee Break' 'Toxic Algae in Coastal Waters'
#  'High Winds, Tornadoes, and Flooding'
#  'High Winds, Wave Action, and Flooding' 'Dam Failure'
#  'Severe Storms, Snow Melt, and Flooding'
#  'Heavy Rains, Snowmelt, and Flooding' 'Mudslides'
#  'Severe Storms and Tornadoes' 'Severe Storms, Flooding, and Tornadoes'
#  'Flooding and Landslides' 'Severe Storms, Flooding, and Landslides'
#  'Severe Storms, Tornadoes, and Flooding' 'Fire (City of Chelsea)'
#  'Severe Storms, Snowmelt, and Flooding'
#  'Freeze in Spawning Areas of Red Salmon' 'Drought and Livestock Losses'
#  'Impact of Drought' 'Power Failure' 'Hurricane Carmen' 'Drought'
#  'Floodng (New York Barge Canal)'
#  'Severe Storms, Landslides, and Flooding'
#  'Severe Storms, High Winds, and High Tides' 'High Winds'
#  'Tornadoes, High Winds, and Heavy Rains'
#  'Tornadoes, High Winds, and Hail' 'Flooding from Rains and Snowmelt'
#  'Rains, Showmelt, Storms, and Flooding'
#  'Heavy Rains, High Winds, Hail, and Tornadoes'
#  'Winds, Tornadoes, Heavy Rains, and Flooding'
#  'Heavy Rains, Tornadoes, and Flash Floods' 'Tropical Storm Elioise'
#  'High Winds, Heavy Rains, and Flooding'
#  'Storms, Rains, Landslides, and Flooding'
#  'Earthquake, Seismic Waves, and Volcanic Eruption' 'Fire and Freezing'
#  'Ice Storm, Severe Storms, and Flooding'
#  'Severe Storms, Tornadoes, Icing, and Flooding'
#  'Severe Storms, Icing, Wind, and Flooding' 'Ice Storms and High Winds'
#  'Severe Flooding' 'Typhoon Marie' 'Typhoon Pamela'
#  'Dam Collapse and Flooding' 'Typhoons Pamela and Therese'
#  'Flash Flooding and Mudslides' 'Flash Flooding'
#  'High Winds and Flash Floods' 'Severe Storms and Flash Flooding'
#  'Hurricane Belle' 'Flooding from Tropical Storm Kathleen' 'Urban Fire'
#  'Ice Conditions' 'Snowstorms' 'Severe Winter Weather'
#  'Drought and Freezing' 'Shrimp Loss Due to Cold Weather'
#  'Winds, Hail, and Rain' 'Severe Storms, Mudslides, and Flooding'
#  'Blizzards and Snowstorms' 'Coastal Storms, Flood, Ice, and Snow'
#  'Coastal Storms, Mudslides, and Flooding' 'Snow and Ice'
#  'High Winds, Tidal Surge, and Coastal Flooding'
#  'Storms, Ice Jams, Snowmelt, and Flooding'
#  'Severe Storms, Flooding, and Mudslides'
#  'Severe Storms, Flooding, Hail, and Tornadoes'
#  'Chemical Waste (Love Canal)' 'Tropical Storm Carmen' 'Landslides'
#  'Brush Fires' 'Typhoon Alice' 'Ice Jam and Flooding'
#  'Rain, Flooding, Mudslides' 'Storms, Tornadoes, Floods'
#  'Storms, Wind, Flooding' 'Tornadoes, Torrential Rain, and Flooding'
#  'High Winds and Tornadoes' 'Severe Storms and Flash Floods'
#  'Storms and Flash Floods' 'Heavy Rains, Flash Floods, and Mud Flows'
#  'Hurricane David' 'Hurricane Frederic'
#  'Hurricane David, Tropical Storm Frederic' 'Tornado and Severe Storms'
#  'Flooding, Mudslides, and Landslides' 'Seawave Action and Flooding'
#  'Storms, High Tides, Mudslides, and Flooding'
#  'Torrential Rain, High Tide, and Winds'
#  'Severe Storms, High Surf, and Flooding'
#  'Severe Storms, Mudslides and Flooding'
#  'Storms, Flood, Mudslides and Tornadoes' 'Undocumented Aliens'
#  'Volcanic Eruption, Mt. St. Helens' 'Hurricane Allen'
#  'Red Tide-Toxic Algae' 'Tropical Storm Danielle'
#  'Levee Break and Flooding' 'Typhoon Dinah' 'Brush and Timber Fires'
#  'Sewer Explosion, Toxic Waste' 'Typhoon Esau'
#  'Severe Storms, Flooding and Tornadoes'
#  'Severe Storms, Flood, Mudslides and High Tide'
#  'Flash Flood Due to Dam Failure' 'Threat of Flooding at Spirit Lake'
#  'Levee Break' 'Typhoon Iwa' 'Severe Storms, High Tides and Flooding'
#  'Coastal Storms, Floods, Slides and Tornadoes'
#  'Severe Storms, Flooding and  Tornadoes'
#  'Severe Storms, Landslides and Flooding'
#  'Severe Storms, Flooding and  Mudslides' 'Coalinga Earthquake'
#  'Hurricane Alicia' 'Severe Storms,Flooding and Tornadoes'
#  'Severe Freezing Weather' 'Ice Jams and Flooding' 'Freezing Temperatures'
#  'Coastal Storms and Flooding' 'High Winds, Tornadoes and Flooding'
#  'Severe Storms, Tornadoes, Hail and Floods'
#  'Severe Storms, Mudslides, Landslides and Flooding' 'Hurricane Diana'
#  'Tropical Storm Klaus' 'Heavy Rain and High Winds' 'Severe Freeze'
#  'Snow Melt and Ice Jams' 'Storms, Mud/Land Slides, Flooding'
#  'Severe Storms, High Winds and Tornadoes'
#  'Grass, Wildlands, and Forest Fires' 'Severe Storms, Hail and Flooding'
#  'Hurricane Elena' 'Hurricane Gloria'
#  'Severe Storms, Flooding and Mudslides' 'Hurricane Juan' 'Hurricane Kate'
#  'Heavy Rains, Snowmelt and Flooding'
#  'Heavy Rains, Landslides and Flooding'
#  'Severe Storms, Rains and Tornadoes' 'Typhoon Lola'
#  'Heavy Rains, Flooding and Mudslides' 'Severe Storms, Flooding'
#  'Severe Storm and Flooding' 'Coastal Storm, High Winds and Waves'
#  'Typhoon Kim' 'Hurricane Tusi' 'Typhoon Orchid'
#  'Storms and Flash Flooding' 'Methane Gas Seepage'
#  'Earthquake and Aftershocks' 'Typhoon Lynn' 'Typhoon Nina'
#  'Tropical Storm Roy' 'Typhoon Roy' 'Rain, Winds, and Tornadoes'
#  'Wildfires' 'Hurricane Gilbert' 'Dike Failure and Flash Flooding'
#  'Severe Freezing' 'Tropical Storm Allison' 'Severe Storms and High Winds'
#  'Hurricane Hugo' 'Loma Prieta Earthquake' 'Typhoon Koryn' 'Hurricane Ofa'
#  'Severe Storms, Tornaodes and Flooding' 'Lava Flow, Kilauea Volcano'
#  'Typhoon Mike' 'Typhoon Owen' 'Typhoon Russ'
#  'Severe Storms and High Tides' 'Heavy Snow, Ice Jams and Flooding'
#  'Severe Storms and Hail' 'Hurricane Bob' 'Hurricane Bob and Flooding'
#  'Hurricane Bob and Severe Storms' 'Oakland Hills Fire' 'Coastal Storm'
#  'Typhoon Yuri' 'Typhoon Zelda' 'Hurricane Val' 'Ice Storm'
#  'Severe Thunderstorms' 'Severe Coastal Storm' 'Tropical Storm Axel'
#  'Typhoon Axel' 'Rain/Snow/Wind Storms, Flooding, Mudslides'
#  'Heavy Rains, Ice Jams and Flooding'
#  'Fire During A Period of Civil Unrest' 'Thunderstorms, Hail and Flooding'
#  'Hurricane andrew' 'Typhoon Omar' 'Old Gulch and Fountain Fires'
#  'Excessive Rain and Hail' 'Hurricane Iniki' 'Water Contamination'
#  'Wind Storms, Tornadoes and Hail' 'High Winds, Heavy Rains and Tornadoes'
#  'Severe Thunderstorms and Tornadoes' 'Typhoon Gay'
#  'Winter Storm and Coastal Flooding'
#  'Coastal Storm, High Tides, Heavy Rain, and Flooding'
#  'Winter Coastal Storm' 'Severe Coastal Storm and Flooding'
#  'Severe Winter Storm, Mud and Land Slides, and Flooding'
#  'Tornadoes, High Winds and Heavy Rains' 'Severe Storms and High Wind'
#  'Tornadoes, Flooding, High Winds and Tides, Freezing'
#  'Severe Snowfall, Winter Storm'
#  'Blizzards, Severe Winds and Snowfall, Coastal Storm'
#  'Severe Winds and Blizzard, Record Snowfall'
#  'Severe Snowfall and Winter Storm'
#  'Blizzards, High Winds and Record Snowfall' 'Severe Blizzard'
#  'Explosion at World Trade Center'
#  'Heavy Rain, Snowmelt, Ice Jams and Flooding'
#  'Heavy Rain, Snowmelt and Flooding' 'Hurricane Emily'
#  'Extreme Fire Hazard' 'Earthquakes'
#  'Fires, Mud/Landslides, Flooding, Soil Erosion' ' Northridge Earthquake'
#  'Severe Winter Storm, Freeezing Rain and Sleet'
#  'Severe Winter Ice Storm,Flash Flooding' 'Severe Winter Ice Storm'
#  'Severe Winter Storms, Freezing, Flooding' 'Severe Ice Storms, Flooding'
#  'Severe Winter Storms' 'Severe Winter Weather and Ice Storms'
#  'Severe Ice Storms and Flooding'
#  'Severe Weather, Freezing Rain, Sleet, Snw'
#  'Severe Storms, Tornado, and Flooding'
#  'Tornadoes, Flooding, and Severe Storms'
#  'Extensive Rainfall and Flash Flooding'
#  'Severe Storms, Tornadoes, Flooding' 'Severe Snow and Ice Storm'
#  'Severe Deep Freeze' 'Flooding and Ice Jams'
#  'Tornadoes, Flooding Torrential Rain(Trop Storm Alberto)'
#  'Severe Storms and Flooding (Tropical Storm Alberto)'
#  'Tropical Storm Alberto' 'The El Nino (The Salmon Industry)'
#  'High Surf and Wave Action' 'Severe Thunderstorms and Flooding'
#  'Heavy Rains, Tornados, Flooding, High Winds'
#  'Tropical Storm Gordon Tornadoes Flooding Rainfall'
#  'Severe Winter Storms, Flooding, Landslides, Mud Flows'
#  'Severe Winter Storms, Flooding Landslides, Mud Flow'
#  'Explosion at Federal Courthouse in Oklahoma City'
#  'Severe Storms, Flooding, and Ground Saturation'
#  'Severe Storms, Tornadoes, Hail, Flooding'
#  'Tornadoes, Severe Winds, Hail'
#  'Severe Storms, Hail, Flooding, and Tornadoes'
#  'Severe Storms, Heavy Rains, Flooding, Mudslides' 'Hurricane Erin'
#  'Excessive Rainfall, Flooding'
#  'Severe Thunderstorms, Winds, Flooding, Tornadoes, and Heat'
#  'Hurricane Marilyn' 'Hurricane Opal'
#  'Severe Storms, Flooding, High Winds'
#  'Excessive Rainfall, High Winds, and Flooding'
#  'Severe Storms, High Wind, and Flooding'
#  'High Winds, Freezing Rain, Heavy Snowfall'
#  'Blizzard of 96 (Severe Snow Storm)' 'Blizzard of 96 ' 'Blizzard 0F 96 '
#  'Flooding, High Winds, and Wind Driven Rain'
#  'High Winds, Severe  Storms and Flooding'
#  'High Winds, Severe Storms and Flooding' 'Winter Storm'
#  'Severe Winter Storms, Ice and Flooding'
#  'Severe Storms, Flooding, and Ice Jams' 'Extreme  Fire Hazard'
#  'Severe Storms, Ice Jams, Flooding' 'Severe Storms  and High Winds'
#  'Blizzard of 96' 'Severe Storms, Flooding, Ice Jams, Soil Saturation'
#  'Severe Storms, Mudslides, Flooding' 'Flooding, Heavy Winds'
#  'Flooding and Severe Storms' 'Severe Storms,Flooding, and  Ice Jams'
#  'Wildland Fires' 'Flooding, Severe Storms'
#  'Extreme Rainfall and Flooding' 'Hurricane Bertha'
#  'Heavy Rains, High Winds, Flooding, and Slides'
#  'Severe Storms, and Flooding' 'Hurricane Fran'
#  'Hurricane Fran and Associated Severe Storm Cond' 'Hurricane Hortense'
#  'Hurricane Fran and Associated Heavy Rains,Flooding Highwind'
#  'Flooding Associated With Tropical Depression Fran'
#  'Severe Storms and Flooding Assoc With Tropical Storm Fran'
#  'Severe Winds and Flooding Assoc With Hurricane Fran'
#  'Tropical Storm Josephine' 'Extreme Weather Conditions and Flooding'
#  'Severe Firestorms' 'Severe Storm,Heavy Rains, Flooding, High Winds'
#  'Extreme Weather Conditons and Flooding' 'Fall Northeaster Rainstorm'
#  'Severe Storms, Flooding, Heavy Rains, High Winds'
#  'Major Water Main Break' 'Gas Leak Explosion'
#  'Prolonged and Heavy Rains, High Surf,Flooding,Land/Mud Slide'
#  'Severe Storms High Winds, Rain and Flooding'
#  'Flooding, Land, Mud Slides, High Winds,Severe Storms'
#  'Severe Thunderstorms, High Winds,Rain, Flooding'
#  'Severe Storms, Flooding, Mud and Landslides'
#  'Severe Winter Storms and Blizzard Conditions'
#  'Severe Winter Storms, Land and Muds Slides,Flooding'
#  'Severe Winter Storms, Land and Mudslides, Flooding'
#  'Severe Storm, Flooding, and Tornadoes'
#  'Heavy Rains, Tornadoes, Flooding, Hail, High Winds'
#  'Heavy and Wind Driven Rain, High Winds,Flooding,Slides' 'Typhoon Fern'
#  'Severe  Winter Storm'
#  'Heavy Rains, Snow Melt, Flooding, Land and Mud Slides'
#  'Severe Flooding, Sever Winter Storms,Heavy Rains High Winds'
#  'Severe Flooding,Severe Winter Storms, Snowmelt, Spring Rains'
#  'Severe Flooding, High Winds,Severe Storms'
#  'Severe Storms, Snowmelt, Land/Mud Slides, Flooding'
#  'Severe Storms, Tornadoes,and Flooding' 'Fl00Ding, Snow Melt'
#  'Severe Storms,Ice Jams, Snow Melt, Flooding'
#  'Severe Storms, Flooding,High Winds, Assoc With Hurr Danny'
#  'Severe Storms, Heavy Rain, Flash Floods, Flooding, Mudslides'
#  'Severe Storms, Tornadoes, High Winds, Flooding'
#  'Severe Snow Storms, Rain, and Strong Winds' 'Severe Snowstorms'
#  'Super Typhoon Keith'
#  'Typhoon Paka, Torrential Rains, High Winds, High Surf'
#  'Super Typhoon Paka' 'Severe Storms, High Winds, Tornadoes, and Flooding'
#  'Severe Ice Storms, Rains and High Winds'
#  'Severe Ice Storm, Rains and High Winds'
#  'Severe Ice Storms, Rain, High Winds and Flooding'
#  'Severe Winter Storms and Flooding'
#  'Severe Winter Storms, High Winds, and Flooding'
#  'Hawaiian Beaches Subdivision Fire'
#  'Severe Winter Coastal Storm, High Winds, Flooding'
#  'Drought, Crop Losses' 'Severe Storms Tornadoes, and Flooding'
#  'Severe Drought' 'Tornadoes, Flooding High Winds'
#  'Flooding, Severe Storms, Tornadoes'
#  'Debruce Grain Elevator Explosion  (Sedgwick Cty)'
#  'Flooding, Ground Saturation,Severe Storms'
#  'Severe Storms, Straight Line Winds, and Tornadoes'
#  'Extreme Fire Hazards' 'Severe Storms and Tornadoes, and Flooding'
#  'Severe Storms,Straigh Line Winds, Tornadoes,Rain,and Floodi'
#  'Wa - Cleveland Fire - 07/28/98' 'Tropical Storm Charley'
#  'Hurricane Bonnie' ' Hurricane Earl' 'Ny - Severe Wx, Sept 7, 1998'
#  'Hurricane Georges (Direct Federal Assist First 72 Hrs)'
#  'Hurricane Georges/Ts Frances' 'Hurricane Georges - Texas'
#  'Hurricane Georges - 18 Sep 98' 'Hurricane Grorges' 'Hurricane Georges '
#  'Hurricane Georges' 'Wa Storms and Flooding 5/26/98'
#  'Wa Landslide 3/6/98' 'Tx-Flooding 10/18/98' 'Ks-Flooding  10/31/98'
#  'Tropical Storm Mitch' 'Il-Winter Storm  1/1/99'
#  'Riv-Severe Winter Wx 12/23/98' 'Snow' 'In-Winter Storm 12/23/98'
#  'Severe Storms, Tornadoes and High Winds' 'Me - Flooding 10/16/98'
#  'Ar Severe Weather 1-21-99' 'Severe Winter Storms, Ice and Freezing Rain'
#  'Mi - Severe Weather 1/2 /99' 'Ca-Citrus Crop Damage 2/2/99'
#  'Wy - Winter Storm  10/5/98' 'Fischer Fire' 'Tn - Wildfires 4/13/99'
#  'Fl-Fires 04/13/99' 'Okeechobee Fire Complex' 'Fl-Fires 04/15/99'
#  'Ok, Tornadoes 5/3/99' 'Mi - Tower Lake Mountain Fire - 05/06/1999'
#  'Tx, Tornado 5/4/99' 'Jacksonville District Fire' 'Co-Flooding 4/30/99'
#  'Severe Storms, Flooding, Snow, Ice, Ground Saturation, Lanslides, Mudslides, and Tor'
#  'Az - Rainbow Fire - 06/11/1999' 'Mira Loma Fire'
#  'Nv - Flash Flooding 7/8/99' 'Fishel Creek Fire Complex'
#  'Severe Storms, Winds, and Flooding' 'West Point Fire Complex'
#  'Tornado, Severe Thunderstorms, and Hail' 'Wi-Flood-07/20/99'
#  'Reese Creek Fire' 'Hurricane Bret ' 'Topeka Fire'
#  'Severe Ice Storm and Flooding' 'Dalby Springs Fire' 'Midlothian Fire'
#  'Tx-Alcoa Fire' 'Tx-Greenville Fire' 'Ca-Wildfires-08/25/1999'
#  'Hurricane Dennis' 'Pa - Flooding 8/20/99'
#  'Virginia Tropical Storm Dennis 08/27/99' 'Hurricane Dennis '
#  'Hurricane Floyd Emergency Declarations' 'Beaver Creek Fire'
#  'Hurricane Floyd Major Disaster Declarations'
#  'Al - Jackson Farms Fire - 09/18/99' 'Al - Russellville Fire - 09/18/99'
#  'Al - Chelsea Fire - 09/18/99' 'Al - Fayette Fire - 09/18/99'
#  'Al - Macintosh Fire - 09/18/99' 'Al - Lookout Mountain Fire - 09/18/99'
#  'Williams Ranch Fire' 'Tropical Depression Dennis Pa'
#  'Severe Ice Storms, Flooding and Heavy Rains' 'Hurricane Floyd '
#  'Al - Martin School Fire - 09/18/1999' 'Tropical Storm Irene - Florida'
#  'Tropical Storm Floyd ' 'Fl-Hurricane Irene-Dr-Req' 'Bluestem Fire'
#  'Tropical Storm Floyd' 'Hurricane Lenny' 'Ky,  Wildfires #001'
#  'Jordan Creek Fire' 'Hurricane Lenny Major Declaration' 'Warehouse Fire'
#  'Saddleback Fire' 'Purgatory Fire' "Bob's Trail Fire"
#  'Tornadoes, Severe Storms, Torrential Rains, and Flash Flooding'
#  'Nv - Spring Creek Fire - 1999' 'Severe Winter Storm '
#  'Severe Storms/Tornados ' 'Severe Winter Storms and Avalanches'
#  'Flooding, Severe Storms, and Landslides' 'Two Fork Fire'
#  'Camden Fire Complex' 'Hawaii County Fire Complex' 'Fl - Merritt Fire'
#  'Rio Grande Fire Complex' 'Cree Fire' 'Severe Fire Threats'
#  'Severe Thunderstorms and Flash Flooding' 'Severe Forest Fire'
#  'Scott Able Fire' 'Flowers-Myakka Fire Complex'
#  'Withlacoochee Fire Complex'
#  'Severe Winter Storm, Flooding, Landslides and Mudslides'
#  'Lakeland District Fire' 'Fl, Bunnell Fire Complex'
#  'Fl, Orlando District Fire Complex' 'Fl, Waccasassa Fire Complex'
#  'Viveach Fire' 'Fl, Jacksonville Fire Complex'
#  'Fl, Suwannee Fire Complex' 'Fl, Perry Fire Complex' 'High Meadows Fire '
#  'Bobcat Gulch Fire ' 'Nm-La Cueva Fire'
#  'Severe Storms, Flooding and Ground Saturation' 'Reno Fire Complex'
#  'Wa-Wildfire-07-24-2000' 'Mt - Central Zone 3B Fire Complex'
#  'Wy - Dead Horse Fire' 'Nv - Arrowcreek Fire'
#  'Mt-Southwestern Zone Two Fire Complex'
#  'Mt - Central Zone 3C Fire Complex' 'Flagpole Fire Complex'
#  'Mt - Northwestern Zone 1 Fire Complex'
#  'Mt - South Central Zone 4 Fire Complex' 'Tx-Chicken Fire-0823-00'
#  'Sd Jasper Fire Ir #3' 'Wa - Mule Dry Fire - 2000'
#  'Tx - Live Oak Loop Fire' 'Mt - Willie Fire'
#  'Tx - Ranger Hill Fire - 8/30/00' 'Tx - Moore Branch Fire - 09/03/00'
#  'Tx - Stanley Mainline Fire - 09/04/00'
#  'Tx - Warren Chapel Fire - 09/04/00' 'Tx - Peach Creek Fire - 09/04/00'
#  'Tx - Sheppard Reese Fire - 09/04/00'
#  'Tx - Mesquite Creek Fire - 09/08/00' 'Tx - Frost Fire - 09/08/00'
#  'Tx-Deep Creek Fire-9/8/00' 'Tx-Milam Street Fire-9/9/00'
#  'La-Western Louisiana Fire Complex-9/8/00' 'Co - Eldorado Fire'
#  'Al - County Line Fire - 09/17/2000' 'Tx-Pine Cove Fire-9/18/00'
#  'Ok-Arbuckle Fire Complex-9/18/00' 'Ok-Bristow Fire Complex-9/18/00'
#  'Ok-Oakcliff Fire Complex-9/21/00' 'Severe Storms and Tornado '
#  'Tropical Storm Helene ' 'Tx - Quail Run Fire - 10/03/00'
#  'West Nile Virus' 'Mn - Carlos Edge Fire Complex - 10/19/2000'
#  'Tn - Knoxville Fire Complex - 11/02/00'
#  'Tn - Cookeville Fire Complex - 11/03/00'
#  'Tn-Greeneville Fire Complex-11/03/00'
#  'Ky - Southeastern District Fire Complex - 11/03/00'
#  'Ky - Eastern District Fire Complex - 11/03/00'
#  'Severe Winter and Ice Storm' 'Severe Winter Storms and Tornadoes'
#  'Tx - Alsbury Fire - 08/29/00' 'Tx - Amhurst Street Fire - 09/04/00'
#  'Illinois Winter Snow Storms' 'Severe Freeze '
#  'Fl - Okeechobee Complex Fire' 'Fl - Caloosahatchee Fire Complex'
#  'Fl - Lakeland Complex Fire' 'Fl - Orlando Complex Fire'
#  'Fl - Myakka Complex Fire' 'Fl - Everglades Fire Complex - 04/25/01'
#  'Severe Storms, Hail, Flooding and Tornadoes'
#  'Flooding, Severe Storms and Tornadoes'
#  'Fl - Chipola River Fire Complex - 05/15/01'
#  'Severe Winter Storms, Flooding, and Tornadoes'
#  'Severe Winter Storms, Flooding and Tornadoes'
#  'Fl - Escambia Fire Complex - 05/16/01'
#  'Severe Winter Storms, Flooding, and Ice Jams' 'Perry Fire Complex'
#  'Ga - Blounts Pasture Fire' 'Nm -Trap and Skeet Fire - 06/02/2001'
#  'Severe Storms, Flooding and Landslides'
#  'Tx-Tropical Storm Allison-06-06-2001' 'Ak - Red Fox Fire - 06/30/01'
#  'Nv - Ten Mile Fire - 07/05/2001'
#  'Wy Wildfire -Green Knoll- July 23, 2001'
#  'Wa - Union Valley Fire - 07/28/01'
#  'Wy- Elk Mountain Fire Complex - 08/01/01'
#  'Sd - Elk Mountain Fire Complex - 08/01/01'
#  'Nv - Antelope Fire - 08/09/2001' 'Wa - Icicle Fire Complex - 2374'
#  'Wa - Virginia Lakes Complex - 2372' 'Wa Brewster Fire Complex 2373'
#  'Or  Bridge Creek Fires 2375' 'Wa Spruce Dome Fire Complex 2377'
#  'Wa Tonasket Fire Complex 2376' 'Or Monument Complex 2380'
#  'Wa - Rex Creek Fire Complex - 2379' 'Wa - Mt Leona Fire Complex - 2378'
#  'Ut - Mollie Fire - 08/19/01' 'Wy - Mcfarland Divide Fire - 09/06/01'
#  'Fires and Explosions'
#  'Severe Storms, Tornadoes, and Flooding Associated With Tropical Storm Gabrielle'
#  'Severe Storms and A Tornado' 'Co - Armageddon Fire - 11/01/01'
#  'Ky - Eastern Fire Complex - 11/02/2001'
#  'Ky - Kentucky River Complex - 11/02/01'
#  'Ky - Southeastern Fire Complex - 11/02/01'
#  'Tn - Chattanooga Fire Complex - 11/03/01'
#  'Sc - Long Bay Fire - 11/09/2001' 'Tn - Ridge Crest Fire - 11/14/2001'
#  'Wv - Southeast Fire Complex - 11/16/2001'
#  'Wv - Trough and Smoke Hole Fire Complex - 11/16/2001'
#  'Va - Far Southwest Fire Complex - 11/16/2001'
#  'Al - North East Alabama Fire Complex - 11/20/2001'
#  'Va - Heard Mountain Fire Complex - 11/20/2001'
#  'Va - Shenandoah Gap Fire Complex - 11/20/01'
#  'Severe Storms, Flooding, Mudslides and Landslides' 'Gavilan Fire'
#  'Va - Fultz Run Fire - 02-28-2002' 'Severe Winter Storm With High Winds'
#  'Nm-Kokopelli Fire Complex-3-23-02' 'Co - Snaking Fire - 4/23/2002'
#  'Az-Ryan-Wildfire-4/30/2002' 'Nm - Penasco Fire - 05-01-02'
#  'Cuerno Verde Fire' 'Black Mountain Fire' 'Nm - Dalton Fire - 05/06/02'
#  'Antonio Fire' 'Az - Indian Fire - 5/15/2002'
#  'Nm - Borrego Fire - 5-23-02' 'Co - Schoonover Fire - 05/23/02'
#  'Typhoon Mitag' 'Mn - by-Pass Fire - 05/31/2002'
#  'Nj - Double Trouble Wildfire - 6/02/02' 'Iron Mountain Fire'
#  'Co - Spring Fire - 06/03/02' 'Co - James John / Fisher - 06/03/02'
#  'Nm-Turkey Fire-6-2-02' 'Nm-Cerro Pelado-6-2-02'
#  'Ca - Copper Fire - 06-06-2002' 'Nm-Ponil Fire-06/02/02' 'Ute Pass Fire'
#  'Coal Seam Fire' 'Co - Haymen Fire - 06/09/02'
#  'Nv Wildfire (Pioche) 06-08-2002' 'Co - Dierich Fire - 06/10/02'
#  'Missionary Ridge Fire' 'Nm - Roybal Fire - 06/13/02' 'Bluecut Fire'
#  'Sc-Legends Fire' 'Wy-Hensel Fire-06/07/02 ' 'Rodeo Fire' 'Million Fire'
#  'Az - Chediski Farms Fire - 06/21/2002' 'Co-Wiley Ridge Fire-06/23/02'
#  'Valley Fire' 'Louisiana Fire' 'Nd - Again Fire - 06/29/2002'
#  'Grizzly Gulch Fire' 'Wy - Reese Mountain Fire - 07/01/02'
#  'Ut - Mustang Fire - 07/01/2002' 'Nv - Gondola Fire - 07/03/2002'
#  "Typhoon Chata'An" "Ts Chata'An, Inc Flooding, Mudslides and Landslides"
#  'Az - Oracle Hills Fire - 07/14/2002' 'Co - Burn Canyon Fire - 07/15/02'
#  'Nv - Gate Fire Complex - 07/15/02' 'Or - Winter Fire - 07/15/2002'
#  'Or - Eyerly Fire - 07/13/2002' 'Nv - Lost Cabin Fire - 07/17/02'
#  'Or - Squire Peak/Wall Creek Fire - 07/17/02' 'Big Elk Fire'
#  'Or - Flagtail Fire - 07/19/02' 'Wa - Deer Point Fire - 07/20/02'
#  'Deer Fire' 'Wa - Pickens Fire - 07/24/02'
#  'Or - Sheldon Ridge Fire - 07/25/02' 'Or - Biscuit Fire - 07/28/02'
#  'Timbered Rock Fire' 'Or - Cache Mountain Fire - 07/28/02'
#  'Ca - Pines Fire - 07/30/02' 'Co - Panorama Fire - 07/31/02'
#  'Sd - Battle Creek Fire - 08/18/02' 'Nm - Lakes Fire Complex - 08/26/02'
#  'Wy - Commissary Ridge Fire - 08/31/02' 'Leona Fire' 'Squirrel Fire'
#  'Sierra Fire' 'Williams Fire' 'Croy Fire' 'Tropical Storm Fay'
#  'Tropical Storm Isidore' 'Hurricane Lili' 'Severe Storms and Tornados'
#  'Severe Winter Storms, Flooding, Coastal Erosion and Tidal Surge'
#  'Super Typhoon Pongsona' 'Typhoon Pongsona'
#  'Ca - Wildfire (Pacific Fire) - 01-06-2003'
#  'Loss of Space Shuttle Columbia' 'Loss of the Space Shuttle Columbia'
#  'Severe Winter Storm, Record/Near Record Snow, Heavy Rains, Flooding and Landslides'
#  'Severe Winter Storm and Record/Near Record Snow'
#  'Severe Winter Ice and Snow Storms, Heavy Rain, Flooding, Tornadoes, and Mud and '
#  'Severe Winter Storm, Record/Near Record Snowfall, Heavy Rain,Floodind, and Mudslide'
#  'Severe Storms, Tornadoes, Floods'
#  'Severe Winter Storm, Including High Winds and Freezing Temperatures'
#  'Nm-Walker Fire-05-09-03' 'Severe Winter Cold and Frost'
#  'Hi - Waikoloa Village Fire - 05/18/2003'
#  'Severe Storms, Flooding, Mud and Rock Slides, and Tornadoes'
#  'Heavy Rainfall, Flooding, Landslides, and Mudslides'
#  'Nv - Highway-50 Fire - 06/17/2003' 'Aspen Fire' 'Ash Fire'
#  'Nm-Bosque Fire-06-25-2003' 'Ca - Sawmill Fire - 06-27-2003'
#  'Ca - Tejon Fire - 06-30-2003' 'Ca-Railroad Fire-07-03-2003'
#  'Nv-Red Rock Fire 7-11-03' 'Wa-Middle Fork Fire-07-12-2003'
#  'Kinishba Fire' 'Ut-Causey Fire 07/14/2003' 'Nv-Robb Wildfire-7-14-2003'
#  'Wa-Okanogan City Fire-07-16-2003' 'Hurricane Claudette'
#  'Ok - Big Rock Fire - 07/18/03'
#  'Mt - Missouri Breaks Complex Fire 07/16/03' 'Canyon Fire'
#  'Mt-Robert Fire-07-23-03' 'Mt-Wedge Canyon Fire-07/18/2003'
#  'Co-Cloudy Pass Fire-07/25/2003'
#  'Severe Storms, High Winds, and Heavy Rain'
#  'Tornadoes, Flooding, Severe Storms, and High Winds'
#  'Mt-Hobble Fire-08/07/2003' 'Mt-Missoula/Mineral Fire Zone-08/08/03'
#  'Mt-Cherry Creek Fire -08/06/03' 'Ca-Locust  Wildfire-08-19-2003'
#  'Mt-Lincoln Fire Complex - 08/14/2003' 'Or-Booth Fire-8-19-2003'
#  'Mt-Flathead Fire Zone-8/20/03' 'Power Outage'
#  'Or-Wyeth/Herman Creek Fire 09-02-2003' 'Wa-Needle Fire-09-06-2003'
#  'Ca-Bridge Fire-09-05-2003' 'Or-Cove Road Fire-09-05-2003'
#  'Hurricane Isabel' 'Tropical Storm Henri'
#  'Tropical Storms Henri and Isabel and Related Severe Storms and Flooding'
#  'Nv - Voltaire-2 Fire - 09-29-2003' 'Pass Fire'
#  'Ca-Grand Prix Fire-10-23-2003' 'Old Fire ' 'Ca-Verdale Fire 10-25-2003'
#  'Ca-Mountain Fire-10-26-2003' 'Paradise Fire' 'Ca-Cedar Fire-10-26-2003'
#  'Simi Fire '
#  'Wildfires, Flooding, Mudflow and Debris Flow Directly Related T '
#  'Ca-Whitmore Fire-10-28-2003' 'Co - Cherokee Ranch Wildfire - 10/29/2003'
#  'Co - Overland Wildfire - 10/29/2003'
#  'Co - Buckhorn Creek Fire - 11/11/2003'
#  'Sd - Mill Road Wildfire - 11/19/2003'
#  'Wy - Tongue River Wildfire - 11/19/2003'
#  'Severe Storms, Flooding, Mudslides, and Landslides'
#  'Severe Storms, Flooding, Landslides, and Mudslides' 'Typhoon Lupit'
#  'High Winds, High Surf, and Heavy Rainfall Associated With Tropcial Cyclone Heta'
#  'Severe Storms, Flooding, Snow Melt and Ice Jams'
#  'Co - Picnic Rock Fire - 03/30/2004' 'Typhoon Sudal'
#  'Ca - Pleasure Fire - 04-25-2004' 'Ca-Cerritos Fire-5-04-2004'
#  'Ca-Eagle Fire-05-04-2004' 'Sever Storms, Flooding and Landslides'
#  'Peppin Fire' 'Ca-Gaviota Fire-06-05-2004' 'Three Forks Fire'
#  'Severe Storms, Tornadoes, Flooding, and Mudslides' 'Brookside Fire'
#  'Nm-Bernardo Fire-6-18-2004' 'Willow Fire' 'Verdi Fire Complex'
#  'Flooding As A Result of A Levee Break' 'Boundary Fire'
#  'Co-Mcgruder Fire-07/03/2004' 'Wa-Beebe Fire-07-04-2004'
#  'Ca-Hollow Fire-07-14-2004' 'Waterfall Fire ' 'Ca-Lakeview-07-14-2004'
#  'Ca - Mataguay Fire - 7-13-2004' 'Ca - Pine Fire - 7-13-2004'
#  'Ca-Foothill Wildfire-07-18-2004' 'Ca-Melton Wildfire-07-18-2004'
#  'Ca-Crown Wildfire-07-21-2004' 'Robbers Fire '
#  'Flooding, High Surf, High Winds, and Wind-Driven Rain Associated W Typh Tingting'
#  'High Winds, Flooding, and Mudslides As A Result of Tropical Storm Tingting'
#  'Elk Heights Fire' 'Deep Harbor Fire'
#  'Or-Redwood Highway Wildfire-08-04-2004'
#  'Ca-Calaveras Complex-08-07-2004' 'Ca-Stevens Fire-08--8-2004'
#  'Ak-Bolgen Creek Fire-08-10-2004' 'Ca-Bear Fire-08-11-2004'
#  'Ca Oregon Fire 08-11-2004' 'Wa-Fischer Wildfire-08-11-2004'
#  'Mud Lake Fire' 'Tropical Storm Bonnie and Hurricane Charley'
#  'Ca-French Fire 08-14-2004' 'Ca-Lake Fire 08-14-2004'
#  'Or-Bland Mountain Wildfire-08-20-2004' 'andrew Wildfire' 'Wildland Fire'
#  'Flooding, High Surf, Storm Surge, and High Winds As A Result of Super Typhoon Ch'
#  'Ak-Taylor Complex Fire-09-01-2004' 'Hurricane Charley'
#  'Ca-Bear Fire-09-02-2004' 'Ca-Pattison Fire-09-03-2004'
#  'Severe Storms, Flooding and Tornadoes Associated W Td Gaston'
#  'Ca-Geysers Fire-09-04-2004' 'Hurricane Frances' 'Tropical Storm Frances'
#  'Rix-Ca-Old Highway Wildfire 9/13/04' 'Kawaihae Road Fire Hawaii'
#  'Tropical Storm Gaston' 'Hurricane Ivan'
#  'Tropical Storm Jeanne and Resulting Landslides and Mudslides'
#  'Severe Storms and Flooding Associated With Tropical Depression Frances'
#  'Tropical Depression Ivan' 'Hurricane Jeanne' 'Tropical Storm Jeanne'
#  'Severe Storms and Flooding from the Remanants of Hurricane Jeanne'
#  'Severe Winter Storm, Tidal Surges and Flooding'
#  'Severe Storms, Tornadoes, and Flooding from the Remnants of '
#  'Record/Near Record Snow'
#  'Severe Storms, Flooding, Debris Flows, and Mudslides'
#  'Severe Winter Storm and Record Snow'
#  'Severe Winter Storms, Heavy Rains, and Flooding'
#  'Severe Winter Storms, Flooding, and Mudslides' 'Record Snow'
#  'Record and/Or Near Record Snow'
#  'Tc Olaf, Includ. High Winds and Surf and Heavy Rainfall'
#  'Severe Storms, Flooding, Landslides, and Mud and Debris Flows'
#  'Sd Wildfire Camp Five' 'Vekol Fire-05-26-2005'
#  'Az-Bobby Fire-06-08-2005' 'Az-Hulet Fire-06-11-2005'
#  'Cave Creek Fire Complex ' 'Az-Humbug Fire 06-23--2005'
#  'Good Springs Fire' 'Blue Springs Fire'
#  'Severe Storms, Flooding, Snow Melt, and Ice Jams' 'Mason Fire '
#  'Sd Ricco Fire' 'Sd Skyline #2 Fire 7/16/05' 'Carlin Fire' 'Contact Fire'
#  'Az-Wildfire (Edge Complex) 07-22-2005' 'Ca-Quartz Fire-7-25-2005'
#  'Dirty Face Fire' 'Lalamilo Fire' 'Akoni Pule Highway Fire' 'School Fire'
#  'Nanakuli Brush Fire' 'Waikele Fire' 'Vor-Mccarty Fire'
#  'Tropical Storm Cindy' 'Deer Creek Fire' 'Manton Fire'
#  'Hurricane Katrina' 'Chance Fire' 'Hurricane Katrina Evacuation'
#  'Sundevil Fire' 'Hurricane Katrina ' 'Hurricane Katrina Evacuees'
#  'Hurricane Ophelia' 'Tropical Storm Rita ' 'Hurricane Rita'
#  'Hurricane Rita ' 'Topanga Fire' 'Border # 50 Fire' 'Woodhouse Fire'
#  'Hurricane Wilma' 'Typhoon Nabi'
#  'Severe Winter Storm and Record and/Or Near Record Snow'
#  'Flat Rock Fire Complex' 'Antioch Fire ' 'Velma Fire Complex '
#  'Severe Storms and Tornadoes ' 'Texanna Road Fire'
#  'Severe Fall Storm, Tidal Surges, and Flooding' 'Achille Fire Complex'
#  'Hughes County Fire Complex' 'Kennedale Fire' 'Callahan County Fire'
#  'Eastern Oklahoma County Fire Complex' 'Wainwright Fire Complex'
#  'Ringgold Fire ' 'Depew Fire Complex' 'Carbon Fire'
#  'Cashion Fire Complex  ' 'Guthrie Fire' 'Sapulpa Fire Complex'
#  'Prague Fire ' '63Rd Street Fire' 'Shamrock Fire Complex'
#  'Bethel Acres Fire ' 'Southeast New Mexico Fire Complex' 'Eufaula Fire'
#  'Mill Creek Fire ' 'Rosewood Fire ' 'Bulverde Fire' 'Cedar Creek Fire'
#  'Mcnally Flats Fire' 'Hawkins Fire ' 'Mauricio Canyon Fire'
#  'Henryetta Fire ' 'Extreme Wildfire Threat' 'Niederwald Fire '
#  'Lockhart Fire' 'Ratcliff Fire' 'Caddo Fire' 'North Stillwater Fire'
#  'Stecker Fire' 'Kiefer Fire' 'Ryan Fire' 'Paoli Fire' 'Sperry Fire'
#  'Orchard Fire' 'Huntington Brook Fire' 'Venus Fire Complex' 'Casa Fire'
#  'Obee Fire' 'New Castle Fire' 'Cement Fire' 'Ponca City Fire '
#  'Ojo Feliz Fire' 'Severe Storms, Tornadoes, and Straight Line Winds'
#  'Bull Mountain Fire' 'Volusia Fire Complex'
#  'Severe Storms, Flooding, Tidal Surge, Landslides, and Mudslides'
#  'Lake Olympia Fire' 'La Barranca Fire' 'Parks Highway (Tamarack) Fire'
#  'Potato Fire' 'Woody Fire' 'Malpais Fire' 'Brins Fire' 'Malo Vega Fire'
#  'Rivera Mesa Fire' 'Suzie Fire' 'North Trinity Fire'
#  'Linehan Fire Complex' 'Oregon Fire'
#  'Severe Storms, Tornadoes, Straight Line Winds, and Flooding'
#  'Saunders Fire' 'Sawtooth Fire Complex ' 'Thorn Divide Fire Complex'
#  'Big Rock Fire ' 'Horse Fire' 'Foster Gulch Fire Complex'
#  'Black Crater Fire' 'East Ridge Fire' 'Dawes County Fire Complex'
#  'Sioux County Fire Complex' 'Junction Fire'
#  'Severe Storms, Straight Line Winds, and Flooding'
#  'Snow Melt and Ice Jam Flooding' 'Valley Mill Fire' 'Verdi Fire'
#  'Jackson Canyon Fire' 'Purgatory Road Fire' 'Caddo Ii Fire Complex'
#  'Emerald Hills Fire' 'Columbia Fire Complex' 'Mudd Fire' 'Derby Fire'
#  'Red Apple Fire ' "Ma'Alaea Fire" 'Flick Creek Fire' 'Moore Road Fire'
#  'Tropical Depression Ernesto, Severe Storms and Flooding' 'Day Fire'
#  'Lake Effect Snowstorm' 'Esperanza Fire' 'Pinehaven Fire'
#  'Rim Rock Fire ' 'Shekell Fire' 'Severe Winter Storms '
#  'Severe Winter Storm, Landslides, and Mudslides'
#  'Severe Winter Storm and Flooding' 'Record Snow and Near Record Snow'
#  'Belen Fire' '241 Fire' '53 Big Pine Fire' 'Sweat Farm Road Fire'
#  'Severe Storms and Inland and Coastal Flooding' 'Kneeknocker Swamp Fire'
#  'Deland Fire Complex ' 'Roundabout Fire' 'Suwannee Fire Complex'
#  'Black Creek Fire ' 'Bugaboo Scrub Fire' 'Calloosahatchee Fire Complex'
#  'Griffith Park Fire' 'Island Fire' 'Warren Grove Fire'
#  'Severe Storms, Flooding, Mudslides, and Rockslides' 'Harveytown Fire'
#  'Newcastle Fire' 'Caribou Hills Fire' 'Angora Fire' 'Olowalu Fire'
#  'Creek Fire' 'Neola North Fire' 'Red Rock Fire' 'Sleeping Elephant Fire'
#  'Milford Flat Fire' 'Inyo Fire Complex' 'Easy Street Fire'
#  'Alabaugh Canyon Fire' 'Hungry Valley Fire' 'Egley Fire Complex'
#  'Tunk Grade Fire' 'Hawken Fire' 'Box Elder Fire' 'Salt Creek Fire'
#  'Murphy Fire Complex' 'Jocko Lakes Fire' 'Little Goose Fire'
#  'Waialua Fire' 'Black Cat Fire' 'Kohala Mountain Road Fire'
#  'Hurricane Dean' 'Ford Road Fire' 'Bridge Collapse' 'Castle Rock Fire'
#  'Cascade Fire Complex' 'East Zone Fire Complex'
#  'Severe Storms, Flooding, and Tornado' 'Gw Fire' 'Angel Fire'
#  'Butler 2 Fire' 'Country Club Fire' 'Broughton Fire'
#  'Tropical Storm Erin' 'Harris Fire' 'Witch Fire' 'Buckweed Fire'
#  'Rice Fire' 'Grass Valley Fire' 'Santiago Fire' 'Ranch Fire'
#  'Wildfires, Flooding, Mud Flows, and Debris Flows' 'Puako Fire'
#  'Ojo Peak Fire' 'Severe Storms, High Surf, Flooding, and Mudslides'
#  'Severe Storms, Tornadoes, Straight-Line Winds, and Flooding '
#  'Chevron Fire' 'Broadway Fire'
#  'Severe Storms, Tornadoes, Straight-Line Winds, and'
#  'Scurry Fire Complex' 'Silver Fire' 'South Woodward Fire'
#  'South Odessa Fire' 'New Archer Fire' 'La Perla Fire' 'Arabella Fire'
#  'Eighty-Two Fire' 'Old Bastrop Highway Fire Complex' '322 Fire'
#  'Encino Fire' 'Burns Ranch Fire' 'Quinlan Fire' 'Silver Heels Fire'
#  'Kentwood Fire' 'Parker Fire' 'Ordway Fire' 'Hebbronville Fire'
#  'Trigo Fire' 'Santa Anita Fire' 'Price Fire' 'Brevard Fire Complex'
#  ' Severe Storms, Tornadoes, and Flooding'
#  'Severe Storms, Tornadoes, Flooding, Mudslides, and Landslides'
#  'Summit Fire' 'Severe Winter Storm and Record and Near Record Snow'
#  'Rein Street Fire' 'Hughes Ranch Fire' 'Gotebo Fire' 'Ophir Fire'
#  'Martin Fire' 'Humboldt Fire' 'Evans Road Fire' 'Camp Bowie Fire'
#  'Severe Storms, Tornadoes, Flooding, Mudslides, and' 'Trabing Fire'
#  'Wild Fire' 'Big Springs Fire' 'Nash Ranch Fire' 'Lane 2 Fire'
#  'Basin Fire Complex' 'Gap Fire' 'Camp Fire'
#  'Badger Mountain Fire Complex' 'Spokane Valley Fire'
#  'Severe Storms, Straight-Line Winds, and Flooding' 'Hurricane Dolly'
#  'Florence Fire' 'Severe Storms, A Tornado, and Flooding'
#  'Hurricane Gustav' 'Hurricane Gustav ' 'Gladding Fire' 'Hurricane Ike'
#  'Royce Butte Fire'
#  'Severe Storms and Flooding Associated With Hurricane Gustav'
#  'Severe Storms and Flooding Associated With Hurricane Ike'
#  'Tropical Storm Hanna'
#  'Severe Wind Storm Associated With Tropical Depression Ike' 'Marek Fire'
#  'Sesnon Fire' 'Tropical Storm Ike' 'Hurricane Omar'
#  ' Severe Storms, Flooding, and A Tornado' 'Tea Fire'
#  'Freeway Fire Complex' 'Sayre Fire' 'Olde Stage Fire'
#  '56Th Presidential Inauguration'
#  'Severe Winter Storm, Landslides, Mudslides, and Flooding' 'Clyde Fire'
#  'Rhodes Ranch Fire' 'Wilderness Ridge Fire'
#  'Severe Winter Storm, Record and Near Record Snow' 'Loma Del Norte Fire'
#  'Taloga Fire' 'Tuscola Fire' 'Greenwood Fire' 'Lagarto Fire'
#  'Magic City Fire' 'Holiday Beach Fire' 'Steel Fire' '617 Fire'
#  '1148 Fire' 'Mulhall Fire' 'Velma Fire' 'Healdton Carter Fire'
#  'Breckenridge Fire' 'Mcclain County Fire' 'Midwest Choctaw Fire'
#  'Cement Mountain Fire' 'Montague Fire Complex' 'Electra West Fire'
#  'Severe Storms, Flooding, Tornadoes, and Straight-Line Winds'
#  'Highway 31 Fire' 'Severe Storms, Flooding, Tornadoes and Straight-Line'
#  'Jesusita Fire' 'Buckwood Fire' 'Martin County Fire Complex'
#  'Mile 17 East End Road Fire' 'Mule Pass Fire'
#  'Severe Storms, Tornadoes, Flooding and Mudslides'
#  'Severe Storms, Tornadoes, Flooding, and Straight-Line Winds'
#  'Severe Storms, Flooding, Straight-Line Winds, and Tornadoes'
#  'Severe Storms, Tornadoes, Straight-Line Winds, and Flooding'
#  'Union Valley Fire' 'Lockheed Fire'
#  'Severe Storms, Straight-Line Winds and Flooding' 'Yuba Fire'
#  'Dry Creek Fire Complex ' 'Oden Road Fire' 'Station Fire'
#  'Microwave Fire' 'Pv Fire ' 'Mill Flat Fire' 'Water Wheel Fire'
#  'Kaunakakai Fire' 'Oak Glen Fire' '49 Fire' 'Pendleton Fire'
#  'Eagle Mount Fire' 'Guiberson Fire' 'South County Fire Complex'
#  'Earthquake,Tsunami, and Flooding' 'Twin Fire' 'Sheep Fire'
#  'Explosions and Fire '
#  "Severe Storms and Flooding Associated With Tropical Depression Ida and A Nor'East"
#  'Tropical Storm Ida'
#  "Severe Storms and Flooding Associated With Tropical Depression Ida and A Nor'Eas"
#  "Severe Storms and Flooding Assoc W Td Ida and Nor'Easter" 'Snowstorm'
#  'Severe Winter Storm and Snowstorm' 'Severe Winter Storms and Snowstorm'
#  'Severe Winter Storms, Flooding, and Debris and Mud Flows'
#  'Severe Winter Storms and Snowstorms' 'Severe Storms and  Flooding'
#  'Water Main Break'
#  'Severe Storms, Flooding, Straight-Line Winds, and Tornadoes '
#  'Severe Storms, Flooding, Mudslides, and Tornadoes' 'Flooding '
#  'Severe Storms, Tornadoes, and Straight-Line Winds' 'Cabazon Fire'
#  'Rio Fire' 'Maalaea Fire' 'Hardy Fire' 'Shultz Fire'
#  'Tropical Storm Alex' 'Cathedral Fire' 'Cowiche Mills Fire' 'Bull Fire'
#  'West Fire' 'Crown Fire' 'Hurricane Alex' 'Post Fire' 'Hurd Fire'
#  'Slide Creek Wildfire' 'Hurricane Earl' 'Four Mile Canyon Fire'
#  'Glenview Fire' 'Reservoir Road Fire' 'Machine Gun Fire '
#  'Severe Storms, Flooding, and Straight-Line Winds '
#  'Severe Storms, Flooding, Tornado, and Straight-Lin'
#  'Severe Storms, Flooding, Mudslides, and Landslides Assoc W Ts Otto'
#  'Severe Storms, Flooding, Rockslides, and Mudslides Assoc. With Ts Tomas'
#  'Severe Winter Storm, Flooding, Mudslides, Landslides, and Debris Flows'
#  'Smith Fire' 'Coffman Fire' 'Tanglewood Fire Complex' 'Matador Fire'
#  'Willow Creek South Fire Complex' 'Mitchell Fire Complex'
#  'Quail Ridge Fire' 'Midwest City Fire Complex' 'Harrah Fire' 'Enmin Fire'
#  'Shawnee Fire' 'Goldsby Fire' 'Big Trickle Ranch Fire'
#  'Indian Gulch Fire' 'Severe Winter Storm and Extreme Cold Temperatures'
#  'Osage County Fire Complex' 'Tsunami Wave Surge'
#  'Severe Winter Storm, Flooding, Landslides, and Mudslides'
#  'Elan Church Road Fire' 'Mosley Road Fire' 'Bates Field Fire'
#  'White Fire ' 'Guymon Fire ' 'Haskell County Fire' 'Crystal Fire'
#  'El Cenizo Fire' 'Jones Spencer Fire ' 'Tsunami Waves' 'Hickman Fire '
#  'Rockhouse Fire ' 'Swenson Fire' 'Cleveland Fire ' 'Wildcat Fire'
#  'Wichita Fire Complex' 'Goodyear Plant Fire'
#  'Cooper Mountain Ranch Fire ' 'Pk West Fire ' 'Pk East Fire'
#  'East Sidwynicks Fire ' 'Hohertz Fire' 'Pinnacle Fire ' 'Tire Fire'
#  'Bryson Fire Complex' '148/2332 Fire ' 'Thedford Fire' 'Slope Fire'
#  'Pleasant Farms Fire'
#  'Severe Storms, Tornadoes, Straight-Line Winds, and Associated Flooding'
#  'Oasis Pipeline Fire ' 'Sisk Road Fire ' 'Waggoner Ranch Fire '
#  'Severe Storms, Tornadoes, and Associated Flooding' 'Gage Holland Fire'
#  'Severe Storms, Straight-Line Winds, Tornadoes, and Flooding'
#  'Matt Loop Fire' 'Horseshoe Two Fire'
#  'Flooding, Landslides, and Mudslides' 'Moose Mountain Fire' 'Ceed Fire '
#  'Stone Ridge Fire' 'Pitt Road Fire ' 'Reimer Fire' 'Wallow Fire'
#  'Tejano Canyon Fire ' 'Snyder Fire ' 'Monument Fire' 'Track Fire '
#  'Racepond Wildfire' 'Duckett Fire' 'Grand Mesa Fire'
#  'Sweat Farm Again Fire' 'Forest Brook Fire ' 'Powerline Fire '
#  'County Line Fire ' 'Cowboy Church Fire ' 'Mcdonald 2 Fire '
#  'Dyer Mill Fire' 'White Hat Fire ' 'Boyken Road Fire '
#  'Medicine Park Fire' 'Las Conchas Fire ' 'Little Lewis Fire'
#  'Donaldson Fire ' 'Simmons Road Fire' 'Nolan County Fire Complex'
#  'Edmond Fire' 'Falls Creek Fire'
#  'Severe Storms, Straight-Line Winds, Tornadoes, and' 'Frankhoma 81-Fire '
#  'Mustang Road Fire' 'Turley Fire ' 'anderson Road Fire ' 'Regency Fire'
#  'Coffee Creek Fire ' '265Th West Fire ' 'Cleveland-Mannford Fire Complex'
#  'Cedar Lane Fire' 'Horseshoe Fire ' 'Hurricane Irene' 'Canyon Creek Fire'
#  '101 Ranch Fire' '63Rd and Sooner Road Fire' 'Westminster Fire'
#  'Twin Lakes Fire Complex' 'Tropical Storm Irene' 'Hill Fire'
#  'Ferguson Fire' 'Bastrop County Fire Complex ' 'Hodde Fire'
#  'Steiner Ranch Fire' 'Pedernales Bend Fire' 'Bear Creek Fire'
#  'Riley Road Fire' 'Moonglow Fire' 'Tamina Fire'
#  'Remnants of Tropical Storm Lee' 'Big Oak Fire ' 'Monastery Fire Complex'
#  'Pat Gross Fire ' 'Holbrook Fire' 'Comanche Fire Complex'
#  'Keene Fire Complex' 'Tropical Storm Lee' 'Indian Creek Fire'
#  'Tropical Storm Maria' 'The Remnants of Tropical Storm Lee'
#  'Caughlin Fire' 'Severe Storm and Snowstorm' 'Washoe Fire'
#  'Severe Storms, Tornadoes, Straight-Line Winds and Flooding'
#  'Severe Storms, Straight-Line Winds, and Tornadoes'
#  'Severe Storms, Tornadoes, Straight-Line Winds and '
#  'Severe Storms, Flooding, Mudslides, and Lanslides'
#  'Lower North Fork Fire' 'Livermore Ranch Fire Complex' 'Tre Fire'
#  'Whitewater-Baldy Fire Complex' 'High Park Fire' 'Little Bear Fire'
#  'Blanco (Cr 4901) Fire' 'Romero Fire'
#  'Severe Storm, Tornado, and Flooding' 'Dump Fire' 'Wood Hollow Fire'
#  'Weber Fire' 'Waldo Canyon Fire' 'Dahl Fire' 'Corral Fire'
#  'Clay Springs Fire' 'Ash Creek Fire'
#  'High Park and Waldo Canyon Wildfires' 'Arapahoe Fire ' 'Rose Crest Fire'
#  'Shingle Fire' 'Squirrel Creek Fire ' 'Tropical Storm Debby'
#  'Oil Creek Fire ' 'Severe Storms and Straight-Line Winds' 'Myrtle Fire'
#  'Fair Grounds Fire Complex' 'Severe Storms ' 'Wildfire' 'Noble Fire'
#  'Geary Fire ' 'Freedom and Noble Wildfires' 'Tropical Storm Isaac'
#  'Hurricane Isaac' 'Severe Storm, Straight-Line Winds, and Flooding'
#  'Hurricane Sandy'
#  'Severe Storm, Straight-Line Winds, Flooding, and Landslides'
#  'Severe Storms and Flooding Due to the Remnants of Hurricane Sandy'
#  'Severe Winter Storm, Snowstorm, and Flooding' 'Explosions' 'Explosion'
#  'Black Forest Wildfire' 'Royal Gorge Fire'
#  'Severe Storms, Tornadoes, and Flooding ' 'Severe Storms and Flooding '
#  'Severe Storms, Flooding, Landslides, Mudslides'
#  'Severe Storms, Winter Storms, Tornadoes and Flooding' 'Rim Fire'
#  'Chemical Spill' 'Flooding and Mudslides'
#  'Severe Storms,Tornadoes, and Flooding'
#  'Severe Storms, Straight-Line Winds, Flooding, Landslides, and Mudslides'
#  'Tropical Storm Halong' 'Tropical Storm Iselle'
#  "Pu'U O'O Volcanic Eruption and Lava Flow"
#  'Severe Winter Storms, Snowstorms, Flooding, Landslides, and Mudslides '
#  'Severe Storms, Tornadoes, Flooding, Landslides, and Mudslides'
#  'Severe Winter Storm, Snowstorm, Flooding, Landslides, and Mudslides'
#  'Typhoon Dolphin' 'Typhoon Soudelor'
#  'Severe Storms, Tornadoes, Straight-Line Winds, Flooding, Landslides, and Mudslide'
#  'Valley Fire and Butte Fire' 'Severe Windstorm' 'Wildfires and Mudslides'
#  'Severe Storm and Straight-Line Wind' 'Contaminated Water'
#  'Severe Winter Storm, Straight-Line Winds, Flooding, Landslides, Mudslides, and A T'
#  'Severe Winter Storms, Tornadoes, Straight-Line Winds, and Flooding'
#  'Severe Winter Storms, Straight-Line Winds, Flooding, Landslides, and Mudslides'
#  'Severe Winter Storm and Straight-Line Winds'
#  'Severe Storm, Tornadoes, Flooding, Landslides, and Mudslides'
#  'Hurricane Hermine' 'Hurricane Matthew' 'Severe Stotms and Flooding'
#  'Potential Failure of the Emergency Spillway at Oroville Lake']
# #####################################################
# [nan 'Clay County' 'Alpine County' 'Amador County' 'Butte County'
#  'Colusa County' 'Del Norte County' 'El Dorado County' 'Glenn County'
#  'Humboldt County' 'Lake County' 'Lassen County' 'Marin County'
#  'Mendocino County' 'Modoc County' 'Napa County' 'Nevada County'
#  'Placer County' 'Plumas County' 'Sacramento County' 'San Joaquin County'
#  'Shasta County' 'Sierra County' 'Siskiyou County' 'Solano County'
#  'Sonoma County' 'Stanislaus County' 'Sutter County' 'Tehama County'
#  'Trinity County' 'Tuolumne County' 'Yolo County' 'Yuba County'
#  'Baker County' 'Benton County' 'Clackamas County' 'Clatsop County'
#  'Columbia County' 'Coos County' 'Crook County' 'Curry County'
#  'Deschutes County' 'Douglas County' 'Gilliam County' 'Grant County'
#  'Harney County' 'Hood River County' 'Jackson County' 'Jefferson County'
#  'Josephine County' 'Klamath County' 'Lane County' 'Lincoln County'
#  'Linn County' 'Malheur County' 'Marion County' 'Morrow County'
#  'Multnomah County' 'Polk County' 'Sherman County' 'Tillamook County'
#  'Umatilla County' 'Union County' 'Wallowa County' 'Wasco County'
#  'Washington County' 'Wheeler County' 'Yamhill County' 'Asotin County'
#  'Clark County' 'Cowlitz County' 'Garfield County' 'Grays Harbor County'
#  'King County' 'Kittitas County' 'Klickitat County' 'Lewis County'
#  'Mason County' 'Pacific County' 'Pierce County' 'Skamania County'
#  'Snohomish County' 'Spokane County' 'Wahkiakum County'
#  'Walla Walla County' 'Whitman County' 'Yakima County' 'Ada County'
#  'Bannock County' 'Benewah County' 'Blaine County' 'Boise County'
#  'Bonneville County' 'Camas County' 'Caribou County' 'Cassia County'
#  'Clearwater County' 'Elmore County' 'Gem County' 'Gooding County'
#  'Idaho County' 'Jerome County' 'Kootenai County' 'Latah County'
#  'Minidoka County' 'Nez Perce County' 'Owyhee County' 'Payette County'
#  'Power County' 'Shoshone County' 'Lyon County' 'Storey County'
#  'Washoe County' 'Aitkin County' 'Anoka County' 'Blue Earth County'
#  'Brown County' 'Carver County' 'Cass County' 'Chippewa County'
#  'Chisago County' 'Cottonwood County' 'Crow Wing County' 'Dakota County'
#  'Dodge County' 'Faribault County' 'Fillmore County' 'Freeborn County'
#  'Goodhue County' 'Hennepin County' 'Houston County' 'Isanti County'
#  'Kanabec County' 'Kandiyohi County' 'Kittson County'
#  'Lac qui Parle County' 'Lake of the Woods County' 'Le Sueur County'
#  'McLeod County' 'Mahnomen County' 'Marshall County' 'Martin County'
#  'Meeker County' 'Mille Lacs County' 'Morrison County' 'Mower County'
#  'Nicollet County' 'Norman County' 'Olmsted County' 'Otter Tail County'
#  'Pine County' 'Pope County' 'Ramsey County' 'Redwood County'
#  'Renville County' 'Rice County' 'Roseau County' 'Scott County'
#  'Sherburne County' 'Sibley County' 'Stearns County' 'Steele County'
#  'Swift County' 'Todd County' 'Traverse County' 'Wabasha County'
#  'Wadena County' 'Waseca County' 'Watonwan County' 'Winona County'
# ...
#  'Maricao Municipio' 'Nacogdoches County' 'Bullock County'
#  'Crenshaw County' 'Dale County' 'Geneva County' 'Cheatham County'
#  'Hardeman County' 'McNairy County' 'Robertson County' 'Stewart County'
#  'Weakley County' 'Calloway County' 'Christian County' 'Graves County'
#  'Metcalfe County' 'Conecuh County' 'Lapeer County' 'Oakland County'
#  'Broadwater County' 'Cascade County' 'Fergus County'
#  'Judith Basin County' 'Lewis and Clark County' 'Meagher County'
#  'Pondera County' 'Teton County' 'Toole County' 'Wheatland County'
#  'Gulf County' 'Aguada Municipio' 'Aguadilla Municipio' 'Anasco Municipio'
#  'Camuy Municipio' 'Hatillo Municipio' 'Hormigueros Municipio'
#  'Isabela Municipio' 'Las Marias Municipio' 'Mayaguez Municipio'
#  'Moca Municipio' 'Quebradillas Municipio' 'Rincon Municipio'
#  'San German Municipio' 'Clare County' 'Isabella County' 'Mecosta County'
#  'Midland County' 'Muskegon County' 'Newaygo County' 'Oceana County'
#  'Cortland County' 'Gladwin County' 'Roscommon County' 'Calumet County'
#  'Dane County' 'Sauk County' 'Palau Island State' 'Guam County-equivalent'
#  'Bingham County' 'Banks County' 'Habersham County'
#  'Northern Islands Municipality' 'Hubbard County' 'Burnett County'
#  'Florence County' 'Juneau County' 'Price County' 'Sawyer County'
#  'Shawano County' 'Vilas County'
#  'West Washabaugh Unorganized Territory of' 'Aurora County'
#  'Bennett County' 'Bon Homme County' 'Brule County' 'Charles Mix County'
#  'Corson County' 'Davison County' 'Day County' 'Gregory County'
#  'Haakon County' 'Jerauld County' 'Lyman County' 'McCook County'
#  'Mellette County' 'Miner County' 'Perkins County' 'Roberts County'
#  'Oglala Lakota County' 'Stanley County' 'Sully County' 'Tripp County'
#  'Yankton County' 'Ziebach County' 'Kidder County' 'Imperial County'
#  'Dent County' 'Hickory County' 'St. Francois County' 'Shannon County'
#  'Taney County' 'Texas County' 'Bland County' 'Patrick County'
#  'Wythe County' 'Calaveras County' 'San Mateo County' 'Santa Clara County'
#  'Santa Cruz County' 'Box Elder County' 'Cache County' 'Daggett County'
#  'Duchesne County' 'Emery County' 'Grand County' 'Juab County'
#  'Millard County' 'Piute County' 'Rich County' 'Sanpete County'
#  'Tooele County' 'Uintah County' 'Wasatch County' 'Weber County'
#  "Queen Anne's County" "St. Mary's County" 'Poquoson' 'New Kent County'
#  'Prince George County' 'Eagle County' 'Huerfano County' 'Mesa County'
#  'Moffat County' 'Pitkin County' 'Routt County' 'Flagler County'
#  'Hardee County' 'Highlands County' 'Indian River County' 'Volusia County'
#  'Jay County' 'Parke County' 'Posey County' 'Vigo County'
#  'Columbiana County' 'Darke County' 'Defiance County' 'Preble County'
#  'Bienville Parish' 'Bossier Parish' 'Caddo Parish' 'Claiborne Parish'
#  'Lincoln Parish' 'Morehouse Parish' 'Natchitoches Parish'
#  'Red River Parish' 'Sabine Parish' 'Union Parish' 'Vernon Parish'
#  'Webster Parish' 'West Carroll Parish' 'Attala County' 'Noxubee County'
#  'Alamance County' 'Cabarrus County' 'Caswell County' 'Catawba County'
#  'Davie County' 'Durham County' 'Granville County' 'Guilford County'
#  'Person County' 'Rowan County' 'Stokes County' 'Vance County'
#  'Yadkin County' 'Quay County' 'Roosevelt County' 'Alcona County'
#  'Alger County' 'Alpena County' 'Antrim County' 'Baraga County'
#  'Benzie County' 'Charlevoix County' 'Cheboygan County' 'Gogebic County'
#  'Grand Traverse County' 'Houghton County' 'Kalkaska County'
#  'Leelanau County' 'Luce County' 'Mackinac County' 'Manistee County'
#  'Missaukee County' 'Montmorency County' 'Ogemaw County'
#  'Ontonagon County' 'Oscoda County' 'Otsego County' 'Presque Isle County'
#  'Schoolcraft County' 'Wexford County' 'Norton' 'Dickenson County'
#  'Wise County' 'Mohave County' 'Yavapai County' 'Bear Lake County'
#  'Chatham County' 'Glynn County' 'Elko County' 'Eureka County'
#  'Lander County' 'Sublette County' 'Sweetwater County' 'Uinta County'
#  'Appling County' 'Atkinson County' 'Bacon County' 'Barrow County'
#  'Ben Hill County' 'Brantley County' 'Bulloch County' 'Butts County'
#  'Candler County' 'Charlton County' 'Chattahoochee County' 'Clinch County'
#  'Colquitt County' 'Coweta County' 'Crisp County' 'Dooly County'
#  'Early County' 'Echols County' 'Effingham County' 'Emanuel County'
#  'Glascock County' 'Grady County' 'Gwinnett County' 'Hart County'
#  'Heard County' 'Irwin County' 'Jeff Davis County' 'Jenkins County'
#  'Lanier County' 'McDuffie County' 'Meriwether County' 'Oglethorpe County'
#  'Schley County' 'Screven County' 'Spalding County' 'Taliaferro County'
#  'Telfair County' 'Thomas County' 'Troup County' 'Twiggs County'
#  'Upson County' 'Ware County' 'Wilkes County' 'Autauga County'
#  'Coosa County' 'Marengo County' 'Tallapoosa County' 'Greensville County'
#  'Abbeville County' 'Aiken County' 'Allendale County' 'Bamberg County'
#  'Barnwell County' 'Charleston County' 'Edgefield County'
#  'Greenville County' 'Hampton County' 'Kershaw County' 'Lexington County'
#  'McCormick County' 'Newberry County' 'Orangeburg County' 'Saluda County'
#  'Spartanburg County' 'Anson County' 'Bladen County' 'Columbus County'
#  'Stanly County' 'Golden Valley County' 'Musselshell County'
#  'Avery County' 'Yancey County' 'Auglaize County' 'Mahoning County'
#  'Wyandot County' 'Keweenaw County' 'Bristol County'
#  'Newport County(in PMSA 2480,6480' 'Providence County(in PMSA 6060,6480'
#  'Washington County(in PMSA 5520,6480'
#  'Fairfield County(in PMSA 1160,1930,5760,8040'
#  'Hartford County(in PMSA 1170,3280,5440'
#  'Litchfield County(in PMSA 1170,1930,3280,8880'
#  'Middlesex County(in PMSA 3280,5020,5480'
#  'New Haven County(in PMSA 1160,5480,8880'
#  'New London County(in PMSA 3280,5520' 'Tolland County' 'Billings County'
#  'Bowman County' 'Slope County' 'Big Horn County' 'Converse County'
#  'Hot Springs County' 'Natrona County' 'Niobrara County' 'Washakie County'
#  'Weston County' 'Powder River County' 'Rosebud County'
#  'Stillwater County' 'Treasure County' 'Yellowstone County'
#  'Bandera County' 'Kerr County' 'Shackelford County' 'Throckmorton County'
#  'Young County' 'Estill County' 'Fleming County' 'Trimble County'
#  'Wolfe County' 'Ebeye' 'Ailinglaplap County-equivalent'
#  'Ebon County-equivalent' 'Enewetak County-equivalent'
#  'Jaluit County-equivalent' 'Kili County-equivalent'
#  'Namu County-equivalent' 'Ujae County-equivalent' 'Ouachita County'
#  'Baylor County' 'Foard County' 'Wichita County' 'Wilbarger County'
#  'Oktibbeha County' 'Crockett County' 'Laramie County' 'Dubois County'
#  'Vermillion County' 'Warrick County' 'Allen Parish'
#  'Kosrae County-equivalent' 'Clallam County' 'Island County'
#  'Nolan County' 'Granite County' 'Silver Bow County' 'Montague County'
#  'Palo Pinto County' 'Caddo County' 'Hot Spring County' 'Macoupin County'
#  'Beauregard Parish' 'Winn Parish' 'Salt Lake County' 'Utah County'
#  'La Paz County' 'Fort Bend County' 'Dimmit County' 'Zavala County'
#  'Lemhi County' 'Duplin County' 'Gates County' 'Robeson County'
#  'Sampson County' 'Marlboro County' 'Rio Blanco County'
#  'New Hanover County' 'Pender County' 'Torrance County' 'Berkshire County'
#  'Hampden County' 'Middlesex County(in PMSA 1120,2600,4560'
#  'Worcester County in PMSA 1120,2600,9240' 'Gadsden County' 'Carson City'
#  'Chouteau County' 'Daniels County' 'Petroleum County' 'Ponape'
#  'Motley County' 'McCone County' 'Beckham County' 'Greer County'
#  'Nowata County' 'North Slope Borough' 'Kenai Peninsula Borough'
#  'Matanuska-Susitna Borough' 'Valdez-Cordova Census Area'
#  'Yukon-Koyukuk Census Area' 'Yap County-equivalent'
#  'Majuro County-equivalent' 'Schoharie County' 'Rota Municipality'
#  'Saipan Municipality' 'Tinian Municipality' 'Albany County'
#  'Saratoga County' 'Schenectady County' 'Burleson County'
#  'Truk County-equivalent' 'Kwajalein County-equivalent' 'Bexar County'
#  'Currituck County' 'Dare County' 'Pamlico County' 'Wabash County'
#  'Edmonson County' 'Elliott County' 'Trigg County'
#  'Aleutian Islands Census Subarea' 'Bethel Census Area'
#  'Dillingham Census Area' 'Fairbanks North Star Borough'
#  'Kodiak Island Borough' 'Nome Census Area'
#  'Southeast Fairbanks Census Area' 'Wade Hampton Census Area'
#  'Angelina County' 'Archer County' 'Blanco County' 'Bosque County'
#  'Coryell County' 'Ector County' 'Ellis County' 'Hood County'
#  'Jack County' 'Kaufman County' 'McCulloch County' 'Ochiltree County'
#  'Pecos County' 'Randall County' 'San Augustine County' 'Somervell County'
#  'Van Zandt County' 'Waller County' 'Jackson Parish'
#  'District of Columbia County-equivalent' 'Clarendon County'
#  'Colleton County' 'Darlington County' 'Dillon County' 'Georgetown County'
#  'Horry County' 'Williamsburg County' 'San Francisco County' 'Frio County'
#  'Kinney County' 'Maverick County' 'Uvalde County' 'Muscogee County'
#  'Iroquois County' 'Moultrie County' 'Callahan County' 'Cottle County'
#  'Eastland County' 'Erath County' 'Hansford County' 'Hunt County'
#  'Tom Green County' 'Wharton County' 'Roger Mills County'
#  'Hitchcock County' 'Red Willow County' 'Gila Bend Indian Reservation'
#  'Fountain County' 'Porter County' 'Vanderburgh County'
#  'Pohnpei County-equivalent' 'St. Lawrence County' 'De Soto Parish'
#  'Dawes County' 'Arno County-equivalent' 'Aur County-equivalent'
#  'Lae County-equivalent' 'Lib County-equivalent' 'Pingelap Municipality'
#  'Austin County' 'Bastrop County' 'Brazos County' 'Coleman County'
#  'Gillespie County' 'Lampasas County' 'Llano County' 'Milam County'
#  'Travis County' 'Mili County-equivalent' 'Lea County' 'Carson County'
#  'Bailey County' 'Borden County' 'Castro County' 'Crosby County'
#  'Deaf Smith County' 'Dickens County' 'Gaines County' 'Garza County'
#  'Lynn County' 'Terry County' 'Yoakum County' 'Niihau CCD'
#  'Kalawao County' 'Ailuk County-equivalent' 'Bikini County-equivalent'
#  'Likiep County-equivalent' 'Maloelap County-equivalent'
#  'Mejit County-equivalent' 'Ujelang County-equivalent'
#  'Utrik County-equivalent' 'Wotho County-equivalent'
#  'Wotje County-equivalent' 'Alachua County' 'Evans County' 'Towns County'
#  'Garrett County' 'Barren County' 'Garrard County' 'Menifee County'
#  'Pleasants County' 'Ritchie County' 'Carteret County' 'Swain County'
#  'Transylvania County' 'Bristol' 'Emporia' 'Franklin' 'Manassas'
#  'Manassas Park' 'Southampton County' 'Alfalfa County' 'Woods County'
#  'Woodward County' 'Jefferson City' 'Kansas City' 'Dundy County'
#  'Jewell County' 'Rooks County' 'Trego County' 'Coke County'
#  'Colorado County' 'Concho County' 'Fisher County' 'Glasscock County'
#  'Grimes County' 'Irion County' 'Kimble County' 'Reagan County'
#  'Real County' 'Runnels County' 'San Saba County' 'Schleicher County'
#  'Scurry County' 'Sterling County' 'Stonewall County' 'Sutton County'
#  'Upton County' 'Val Verde County' 'Nondalton ANV/ANVSA'
#  'Northwest Arctic Borough' 'Harmon County' 'Anchorage Borough'
#  'Kenton County' 'Ravalli County' 'Childress County' 'Hendricks County'
#  'Onslow County' 'Hoke County' 'Churchill County' 'Fall River County'
#  'Sweet Grass County' 'Banner County' 'Kimball County'
#  'Scotts Bluff County' 'Chaves County' 'DeBaca County'
#  'Jabat County-equivalent' 'Namorik County-equivalent' 'Carroll' 'Clinton'
#  'Statewide' 'Alabama and Coushatta Indian Reservation'
#  'Ysleta del Sur Pueblo Indian Reservation' 'Andrews County'
#  'Brewster County' 'Crane County' 'Culberson County' 'Dallam County'
#  'Hartley County' 'Hemphill County' 'Lipscomb County' 'Loving County'
#  'Presidio County' 'Reeves County' 'Winkler County' 'Tyrrell County'
#  'Orleans Parish' 'McDonough County' 'Goshen County' 'Fayette'
#  'Devils Lake Sioux Indian Reservation' 'Fort Berthold Indian Reservation'
#  'Standing Rock Sioux Tribe of North & South Dakota'
#  'Turtle Mountain Indian Reservation'
#  'Oglala Sioux Tribe of the Pine Ridge Reservation' 'Roseau'
#  'Mescalero Tribe' 'Luna County' 'Aleutians East Borough' 'Denali Borough'
#  'Lake and Peninsula Borough' 'Socorro County' 'Bernalillo County'
#  'Cibola County' 'Los Alamos County' 'White Earth Indian Reservation'
#  'Beaverhead County' 'Blackfeet Indian Reservation'
#  'Crow Indian Reservation' 'Flathead Indian Reservation'
#  'Fort Belknap Indian Reservation' 'Northern Cheyenne Indian Reservation'
#  "Rocky Boy's Indian Reservation" 'Fallon County'
#  'Fort Hall Indian Reservation' 'Gila River Indian Reservation'
#  'Wibaux County' 'Fond du Lac Indian Reservation'
#  'Mille Lacs Indian Reservation'
#  'Prairie Island Community Indian Reservation'
#  'Red Lake Indian Reservation' 'Upper Sioux Community Indian Reservation'
#  'Box Butte County' 'Garden County' 'Hooker County' 'Keith County'
#  'Morrill County' 'Cimarron County' 'Tok ANV/ANVSA' 'Bond County'
#  'Southern Ute Indian Reservation'
#  'Ute Mountain Indian Reservation Also NM' 'Chaffee County'
#  'White Mountain Apache Tribe' 'Crooked Creek ANV/ANVSA'
#  'Lime Village ANV/ANVSA' 'Red Devil ANV/ANVSA' 'Sleetmute ANV/ANVSA'
#  'Chuuk County-equivalent' 'Chignik Lagoon ANV/ANVSA'
#  'Chignik Lake ANV/ANVSA'
#  'Eastern Band of Cherokee Indians of North Carolina' 'Broomfield County'
#  'Miami-Dade County' 'Cayuga Nation TDSA' 'Oneida East Indian Reservation'
#  'Spirit Lake Reservation' 'Rosebud Indian Reservation' 'Wallace County'
#  'Yukon Flats Regional Educational Attendance Area' 'Dot Lake ANV/ANVSA'
#  'Northway ANV/ANVSA' 'Tanacross ANV/ANVSA' 'Tetlin ANV/ANVSA'
#  'Bering Strait Regional Educational Attendance Area'
#  'Kashunamiut Regional Educational Attendance Area'
#  'Lower Kuskokwim Regional Educational Attendance Area'
#  'Lower Yukon Regional Educational Attendance Area'
#  'Pribilof Island Regional Educational Attendance Area'
#  'Kiowa Township of' 'Hopi Indian Reservation'
#  'Navajo Nation Reservation Also NM and UT' 'Nye County' 'Pershing County'
#  'Havasupai Indian Reservation' 'San Carlos Indian Reservation'
#  'Nez Perce Indian Reservation' 'Uintah and Ouray Indian Reservation'
#  'Gove County' 'Norton County' 'Rawlins County' 'Esmeralda County'
#  'Canyon County' 'Twin Falls County' 'Loup County'
#  'Pyramid Lake Indian Reservation' 'Washoe Indian Reservation'
#  'Warm Springs Indian Reservation'
#  'Yukon Koyukuk Regional Educational Attendance Area'
#  'Navajo Nation Reservation Also  AZ and UT'
#  "Tohono O'odham Reservation and Trust Lands"
#  'Chugach Regional Educational Attendance Area'
#  'Copper River Regional Educational Attendance Area'
#  'Siletz Indian Reservation' 'Bon Homme Township of'
#  'Crow Creek Indian Reservation'
#  'Lake Traverse Sisseton Indian Reservation'
#  'Coos,Lower Unqua and Siuslaw Indian Reservation'
#  'Grand Ronde Indian Reservation' 'Hoopa Valley Indian Reservation'
#  'Yurok Indian Reservation' 'Cheyenne River Indian Reservation'
#  'Lower Brule Indian Reservation'
#  'Alaska Gateway Regional Educational Attendance Area'
#  'Kuspuk Regional Educational Attendance Area'
#  'Yupiit Regional Educational Attendance Area'
#  'Wind River Indian Reservation' 'Pueblo of Acoma'
#  'Flandreau Indian Reservation' 'Mashantucket Pequot Indian Reservation'
#  'Paucatuck Eastern Pequot Indian Reservation' 'Pueblo of Picuris'
#  'Pueblo of Pojoaque' 'Pueblo of San Felipe'
#  'San Felipe Pueblo Indian Reservation' 'Pueblo of Santa Ana'
#  'Pueblo of Santa Clara' 'Pueblo of Taos' 'Fort Peck Indian Reservation'
#  'Cochiti Pueblo Indian Reservation' 'Jemez Pueblo Indian Reservation'
#  'Santa Clara Pueblo Indian Reservation' 'Omaha Indian Reservation'
#  'Southwest Region Regional Educational Attendance Are'
#  'Grand Portage Indian Reservation' 'Red Cliff Indian Reservation'
#  'Crow/Northern Cheyenne Area' 'Mississippi Choctaw Indian Reservation'
#  'Colville Indian Reservation' 'Mattaponi Indian Reservation'
#  'Pamunkey Indian Reservation' 'Karuk Reservation'
#  'Sandia Pueblo Indian Reservation'
#  'Santo Domingo Pueblo Indian Reservation'
#  'Isleta Pueblo Indian Reservation' 'Sauk-Suiattle Indian Reservation'
#  'Stillaguamish Indian Reservation' 'Tulalip Indian Reservation'
#  'Bois Forte Nett Lake Indian Reservation'
#  'Sac and Fox Tribe of the Mississippi in Iowa'
#  'Moapa River Indian Reservation' 'Soboba Indian Reservation'
#  'Kalispel Indian Reservation' 'Spokane Indian Reservation'
#  'Yakama Reservation' 'Catawba Indian Reservation'
#  "Coeur d'Alene Indian Reservation" 'Aleutians West Census Area'
#  'Bad River Indian Reservation']

# %% [markdown]
# # Task 2: Aggregation & Filtering & Rank
# In this task, we will perform some very high level aggregation and filtering operations.
# Then, we will apply ranking on the results for some tasks.
# Pandas has a convenient and powerful syntax for aggregation, filtering, and ranking.
# DO NOT write a for loop. Pandas has built-in functions for all tasks.

# %%
# 8 points
#Task 2-a: Find out the declaration titles of type 'Emergency' which lasted more than 120 days

Emergency_greater_120 = df_data.loc[(df_data['Declaration Type'] == 'Emergency') & ((pd.to_datetime(df_data['Close Date']) - pd.to_datetime(df_data['Start Date'])).dt.days > 120)]['Disaster Title'].unique()
print (">>Task 2-a: The declaration titles of type 'Emergency' which lasted more than 120 days are %s" 
       % (Emergency_greater_120))

# 8 points
#Task 2-b: Find out the total number of declarations between 1998 and 1999 where Individual Assistance Program was provided for the state of Texas.
#


num_declarations_1998_1999 = df_data.loc[(df_data['State'] == 'TX') & (df_data['Individual Assistance Program'] == 'Yes') & (pd.to_datetime(df_data['Declaration Date']).dt.year.isin([1998,1999]))].shape[0]

print ("\n\n>>Task 2-b: The total number of declarations in 1998-1999 for the state of Texas were %s" 
       % (num_declarations_1998_1999))

# 14 points
#Task 2-c: Find out the top 10 counties with the declaration type 'Disaster' and 'Emergency' for all years.
n = 10
top10_disasters=df_data.loc[(df_data['Declaration Type'] == 'Disaster')].groupby('County').size().sort_values(ascending=False).head(n)
top10_emergencies=df_data.loc[(df_data['Declaration Type'] == 'Emergency')].groupby('County').size().sort_values(ascending=False).head(n)
print ("\n\n>>Task 2-c: top 10 counties with the most disasters for all years are: \n%s" % (top10_disasters))
print ("\n\n>>Task 2-c: top 10 counties with the most emergencies for all years are: \n%s" % (top10_emergencies))
# Out:
# >>Task 2-a: The declaration titles of type 'Emergency' which lasted more than 120 days are ['Drought and Livestock Losses' 'Impact of Drought' 'Power Failure'
#  'Floodng (New York Barge Canal)'
#  'Severe Storms, High Winds, and High Tides' 'Tornadoes' 'High Winds'
#  'Heavy Rains and Flooding' 'Drought' 'Urban Fire' 'Snowstorms'
#  'Drought and Freezing' 'Severe Storms, Landslides, and Flooding'
#  'Winds, Hail, and Rain' 'Blizzards and Snowstorms'
#  'Severe Storms and Tornadoes' 'Chemical Waste (Love Canal)' 'Brush Fires'
#  'Flooding' 'Ice Jam and Flooding' 'Rain, Flooding, Mudslides'
#  'Severe Storms and Flooding' 'Torrential Rain, High Tide, and Winds'
#  'Undocumented Aliens' 'Red Tide-Toxic Algae' 'Water Shortage'
#  'Threat of Flooding at Spirit Lake' 'Methane Gas Seepage'
#  'Water Contamination' 'Severe Snowfall, Winter Storm'
#  'Blizzards, Severe Winds and Snowfall, Coastal Storm'
#  'Severe Winds and Blizzard, Record Snowfall'
#  'Severe Snowfall and Winter Storm'
#  'Blizzards, High Winds and Record Snowfall' 'Severe Blizzard'
#  'Severe Winter Storm' 'Extreme Fire Hazard' 'Tropical Storm Alberto'
#  'Hurricane Erin' 'Extreme  Fire Hazard'
#  'Extreme Weather Conditions and Flooding' 'Severe Firestorms'
#  'Severe Storm,Heavy Rains, Flooding, High Winds' 'Major Water Main Break'
#  'Gas Leak Explosion' 'Tornadoes, Flooding High Winds'
#  'Debruce Grain Elevator Explosion  (Sedgwick Cty)' 'Fire'
#  'Extreme Fire Hazards'
#  'Hurricane Georges (Direct Federal Assist First 72 Hrs)'
#  'Hurricane Grorges' 'Hurricane Georges' 'Il-Winter Storm  1/1/99' 'Snow'
#  'In-Winter Storm 12/23/98' 'Mi - Severe Weather 1/2 /99'
#  'Fl-Fires 04/15/99' 'Ca-Wildfires-08/25/1999' 'Hurricane Dennis'
#  'Hurricane Floyd Emergency Declarations' 'Tropical Storm Irene - Florida'
#  'Hurricane Lenny' 'Warehouse Fire' 'Severe Fire Threats'
#  'West Nile Virus' 'Severe Winter and Ice Storm' 'Severe Winter Ice Storm'
#  'Illinois Winter Snow Storms' 'Fires and Explosions'
#  'Loss of Space Shuttle Columbia' 'Loss of the Space Shuttle Columbia'
#  'Power Outage' 'Record/Near Record Snow' 'Record Snow'
#  'Record and/Or Near Record Snow' 'Hurricane Katrina'
#  'Hurricane Katrina Evacuation' 'Hurricane Katrina '
#  'Hurricane Katrina Evacuees' 'Hurricane Ophelia' 'Hurricane Rita'
#  'Severe Storms' 'Lake Effect Snowstorm'
#  'Severe Winter Storms and Flooding' 'Record Snow and Near Record Snow'
#  'Hurricane Dean' 'Bridge Collapse' 'Wildfires' 'Severe Winter Storms'
#  'Hurricane Gustav' 'Hurricane Ike' '56Th Presidential Inauguration'
#  'Explosions and Fire ' 'Water Main Break' 'Tropical Storm Alex'
#  'Hurricane Earl' 'Severe Storms, Tornadoes, and Straight-Line Winds'
#  'Hurricane Irene' 'Remnants of Tropical Storm Lee' 'Severe Storm'
#  'Tropical Storm Isaac' 'Hurricane Sandy' 'Explosion'
#  'Severe Storms, Flooding, Landslides, and Mudslides' 'Chemical Spill']
#
#
# >>Task 2-b: The total number of declarations in 1998-1999 for the state of Texas were 322
#
#
# >>Task 2-c: top 10 counties with the most disasters for all years are:
# County
# Washington County    294
# Jefferson County     286
# Jackson County       271
# Franklin County      265
# Lincoln County       242
# Clay County          220
# Madison County       206
# Montgomery County    205
# Monroe County        197
# Marion County        191
# dtype: int64
#
#
# >>Task 2-c: top 10 counties with the most emergencies for all years are:
# County
# Washington County    107
# Franklin County       94
# Jackson County        80
# Jefferson County      78
# Montgomery County     77
# Monroe County         67
# Lincoln County        66
# Madison County        60
# Marion County         59
# Warren County         59
# dtype: int64

# %% [markdown]
# # Task 3: Visualization
# In this task, you will perform a number of visualization tasks to get some intuition about the data. Visualization is a key component of exploration. You can choose to use either Matplotlib or Seaborn for plotting. The default figures generated from Matplotlib may look unaesthetic and so you might want to try Seaborn to get better figures. Seaborn has a variety of styles. Feel free to experiment with them and choose the one you like. We have assigned 10 points for the aesthetics of your visualizations.

# %%
sns.set_style('whitegrid')
sns.set(font_scale = 1.3)

# 10 points
# Task 3-a: Plot the declaration count for each state . 
# Think of a way to nicely visualize all the states! 
#########################begin code for Task 3-a
width=30
height=20
plt.figure(figsize=(width,height))
statewise_count = sns.countplot('State', data=df_data.sort_values(by='State', ascending=True))
for p in statewise_count.patches:
    statewise_count.annotate(p.get_height(), 
                        (p.get_x() + p.get_width() / 2.0, 
                         p.get_height()), 
                        ha = 'center', 
                        va = 'center', 
                        xytext = (0, 10),
                        textcoords = 'offset points')

plt.title("Statewise declaration count")
plt.xlabel("States")
plt.ylabel("Count")
plt.show()
#########################end code for Task 3-a

# 20 points
# Task 3-b: Draw a pie chart that represents Declaration type.
#########################begin code for Task 3-b 
plt.figure(figsize=[12, 12])
declaration_types = df_data['Declaration Type'].unique()
plt.pie(df_data.groupby('Declaration Type').size(),labels=declaration_types,autopct='%1.2f%%', shadow=True)
plt.title('Declaration Types')
plt.show()
#########################end code for Task 3-b

# %% [markdown]
# # Task 4:
# Find out an 'interesting' information from the dataset. Create a visualization for it and explain in a few lines your reasoning.
#
# This task is worth 20 points. Your result will be judged based on the uniqueness and quality of your work (having a meaningful result and an aesthetic visualization).

# %%
#########################begin code for Task 4
import calendar   ## to convert month number to name
width=30
height=20
plt.figure(figsize=(width,height))
df=DataFrame({'count' : df_data.groupby(pd.to_datetime(df_data['Declaration Date']).dt.month)['Disaster Type'].size()}).reset_index()
df['month'] = df['Declaration Date'].apply(lambda x: calendar.month_abbr[x])
sns.barplot(x="month", y="count", data=df)
plt.title("Monthwise declaration count", {'fontsize': 30})
plt.xlabel("Month",{'fontsize': 30})
plt.ylabel("Total no. of declarations", {'fontsize': 30})
plt.text(0, 11000, "As per FEMA, September is observed as National Preparedness Month and one reason for this is because of the peak", fontsize=24)
plt.text(0, 10500, "of the Atlantic hurricane season is in mid-September. The chart below shows monthwise count of disasters in last 63 years. ", fontsize=24)
plt.text(0, 10000, "The chart clearly shows September has the highest count. (Source:Wikipedia)", fontsize=24)
plt.show()
#########################end code for Task 4
